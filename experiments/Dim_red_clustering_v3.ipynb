# %% [markdown]
# # 0. Setup
# We will begin by importing all required libraries and fixing the plotting setup.

# %%
#imports
import pandas as pd
import numpy as np
import pickle
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import matplotlib.colors as mcolors
import seaborn as sns
import random
import os
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import SpectralClustering
from sklearn.cluster import Birch
from sklearn.cluster import OPTICS
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn import metrics
#colab specific: ######################################################################
# !pip install umap-learn[plot]
# !pip install holoviews
# !pip install -U ipykernel
#######################################################################################
import umap

# %%
#plot settings
# %matplotlib inline
sns.set(style='white', context='notebook', rc={'figure.figsize':(3,3)})
plt.ioff() #ensures that no plots are shown within the notebook if not explicity demanded by plt.show()

#color configuration
colors = list(mcolors.CSS4_COLORS.keys())
colors = random.sample(colors, 100)
colors = np.array(colors)

# %% [markdown]
# # 1. Setting the Parameters
# For a better legibility of this document, we will store all parameter settings in this section.

# %%
#Path to workspace
w_path = '/content/gdrive/MyDrive/DIm_red_Clustering/'

#Pre-processing of the imported data - choose between...
# 'feature_stand': feature standardization leading to unit vairance and zero mean of all features across the samples
# 'norm_vecs': Normalized embedding vectors, that project all embedding vectors on a unit sphere
pre_processing = 'feature_stand'


#Dimensionality reduction of the imported data - choose between...
# 'PCA'
# 'UMAP'
dim_reduction = 'UMAP'


#Data-generation network - choose between...
# 'Mannheim':
# 'adapters':
data_generation = 'Mannheim'

# %% [markdown]
# # 2. Loading the embeddings
#
# Now, we will have to load the user embeddings from the npy file they are stored in.
#
# We also want to check that the imported data has the desired dimensions, to make sure that nothing went wrong throughout the process of creating and storing the embeddings in the npy file, and importing them into this document.

# %%
#colab specific import setup: ######################################################################
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
####################################################################################################

#checking which data to import
if data_generation == 'adapters':
  path='/content/gdrive/MyDrive/DIm_red_Clustering/user_embeddings_adapters.npy'
else:
  path='/content/gdrive/MyDrive/DIm_red_Clustering/user_embeddings_32d.npy'

#loading the data
data = np.load(path)

#create folder to sort images into
data_gen_path = w_path + data_generation
if os.path.exists(data_gen_path) == False:
  os.mkdir(data_gen_path)

#Check that embeddings have the correct shape
print(data.shape)
# Out:
# Mounted at /content/gdrive
# (2062, 32)

# %% [markdown]
# # 3. Pre-processing the embeddings
# Before passing our user embeddings on to the dimensionality reduction, we will have to pre-process them, to make sure that not a few features only dominate the dimensionality reduction due to scale differences.

# %%
#checking which means of data pre-processing to use
if pre_processing == 'norm_vecs':
  scale_factors = np.sum(data, axis = 1)
  scale_factors = scale_factors[:, np.newaxis]
  processed_data = data / scale_factors
else:
  processed_data = StandardScaler().fit_transform(data)

#create folder to sort images into
pre_processing_path = data_gen_path + '/' + pre_processing
if os.path.exists(pre_processing_path) == False:
  os.mkdir(pre_processing_path)

# %% [markdown]
# # 4. Performing Dimensionality Reduction

# %%
#initializing dict to save reduced dimensionality embeddings in, and to retrieve those embeddings based on the parameters used to create them
embeddings = {}

# %%
#Create folders to later deposit images in
path_dimred = pre_processing_path + '/' + dim_reduction
os.mkdir(path_dimred)
path2D = path_dimred + '/' + str(2)
os.mkdir(path2D)
path3D = path_dimred + '/' + str(3)
os.mkdir(path3D)

print(path2D)
print(path3D)

#Checking which means of dimensionality reduction to use
if dim_reduction == 'UMAP':

  #UMAP
  #iterating over plausible hyperparameter values: Dimension, number of neighbors, minimum distance and distance metric
  for n_dims in [2,3]:
    for n_neighbors in range(2,11,1): #n_neighbors in steps of 1 from 2-10
      for min_dist in range(1,10,1): #min_dist between 0 and 1 in steps of 0.1
        for measure in ['euclidean','manhattan','cosine']: #different distance measures

          reducer = umap.UMAP(n_components = n_dims, n_neighbors = n_neighbors, min_dist = min_dist/10, metric = measure) #initialize umap with desired hyperparams
          reduced_data = reducer.fit_transform(processed_data)#calculate umap and return reduced embeddings
          embeddings[data_generation+ pre_processing + dim_reduction + str(n_dims) + str(n_neighbors)+ str(min_dist/10) + measure] = reduced_data #saving embeddings for retrieval during clustering

          if n_dims == 2:
            #plotting result and saving plots as images
            plt.figure()
            plt.scatter(reduced_data[:, 0], reduced_data[:, 1], s=0.1)
            plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + str(n_neighbors)+ '     min_dist:' + str(min_dist/10) + '     metric:' + measure, fontsize=8)
            path2D_image = path2D + '/' + str(n_neighbors) + '_' + str(min_dist/10) + '_' + measure +'.pdf'
            plt.savefig(path2D_image, pad_inches = 15)

          else:
            #plotting result and saving plots as images
            plt.figure()
            ax = plt.axes(projection='3d')
            ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2],s=0.1)
            plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + str(n_neighbors)+ '     min_dist:' + str(min_dist/10) + '     metric:' + measure, fontsize=8)
            path3D_image = path3D + '/' + str(n_neighbors) + '_' + str(min_dist/10) + '_' + measure +'.pdf'
            plt.savefig(path3D_image, pad_inches = 15)

    if os.path.exists(data_gen_path +'/' + 'reduced_embeddings') == False:
      os.mkdir(data_gen_path +'/' +  'reduced_embeddings')

    with open(data_gen_path + '/' + 'reduced_embeddings'+ '/' + 'red_embeddings_UMAP_' + pre_processing + str(n_dims) + '.pickle', 'wb') as file:
      pickle.dump(embeddings, file)


else:
  #PCA
  #iterating over hyperparameter: Dimension
  for n_dims in [2,3]:
    pca = PCA(n_components = n_dims)
    reduced_data = pca.fit_transform(processed_data)
    embeddings[data_generation+ pre_processing + dim_reduction + str(n_dims) + 'na'+ 'na' + 'na'] = reduced_data #saving embeddings for retrieval during clustering

    if n_dims == 2:
      #plotting result and saving plots as images
      plt.figure()
      plt.scatter(reduced_data[:, 0], reduced_data[:, 1], s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction, fontsize=8)
      path2D_image = path2D + '/'+ 'PCA' + '.pdf'
      plt.savefig(path2D_image, pad_inches = 15)

    else:
      #plotting result and saving plots as images
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2],s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction, fontsize=8)
      path3D_image = path3D + '/' + 'PCA' +'.pdf'
      plt.savefig(path3D_image, pad_inches = 15)

# %% [markdown]
# # 5. Selecting suitable reduced embeddings
# As a next step, we will have to visually inspect the resulting plots to determine the most suitable reduced dimensionality embeddings. We will note down the hyperparamters used to create these embeddings.
#
# The chosen embeddings can be retrieved later when clustering by listing the hyperparameters used to create them as a keyword for the "*embeddings*" dictionary.

# %%
#Merging the saved embeddings into one dictionary
umap_feature_stand2 = {}
umap_feature_stand3 = {}
umap_norm_vecs2 = {}
umap_norm_vecs3 = {}
pca = {}
length = 0

with open(w_path + 'adapters' + '/' + 'reduced_embeddings'+ '/' + 'red_embeddings_UMAP_feature_stand2.pickle', 'rb') as file:
    umap_feature_stand2 = pickle.load(file)
    len1 = len(umap_feature_stand2.values())
    length += len1
with open(w_path + 'adapters' + '/' + 'reduced_embeddings'+ '/' + 'red_embeddings_UMAP_feature_stand3.pickle', 'rb') as file:
    umap_feature_stand3 = pickle.load(file)
    len2 = len(umap_feature_stand3.values())
    length += len2
with open(w_path + 'adapters' + '/' + 'reduced_embeddings'+ '/' + 'red_embeddings_UMAP_norm_vecs2.pickle', 'rb') as file:
    umap_norm_vex2 = pickle.load(file)
    len3 = len(umap_norm_vecs2.values())
    length += len3
with open(w_path + 'adapters' + '/' + 'reduced_embeddings'+ '/' + 'red_embeddings_UMAP_norm_vecs3.pickle', 'rb') as file:
    umap_norm_vex3 = pickle.load(file)
    len4 = len(umap_norm_vecs3.values())
    length += len4
with open(w_path + 'adapters' + '/' + 'reduced_embeddings'+ '/' + 'red_embeddings_PCA.pickle', 'rb') as file:
    pca = pickle.load(file)
    len5 = len(pca.values())
    length += len5

embeddings = umap_feature_stand2 | umap_feature_stand3 | umap_norm_vex2 | umap_norm_vex3 | pca
print(embeddings)
# Out:
# {'adaptersfeature_standUMAP220.1euclidean': array([[12.82532  ,  1.9280121],
#        [13.576631 , 14.858982 ],
#        [15.574315 , 10.126566 ],
#        ...,
#        [11.80869  , -1.2324836],
#        [-1.507207 , 11.75822  ],
#        [ 2.4852324, 14.774012 ]], dtype=float32), 'adaptersfeature_standUMAP220.1manhattan': array([[-2.4922097,  2.4435098],
#        [ 2.5095065, -6.0698004],
#        [ 8.163734 , 10.883086 ],
#        ...,
#        [-1.8012158,  1.6931683],
#        [13.7668915,  6.6616306],
#        [ 7.9556355,  7.600185 ]], dtype=float32), 'adaptersfeature_standUMAP220.1cosine': array([[ 0.6771398 ,  1.7429458 ],
#        [ 0.16681385, 15.417144  ],
#        [ 4.8123307 , 13.840278  ],
#        ...,
#        [15.589223  , -2.9510105 ],
#        [15.352176  ,  9.896031  ],
#        [ 5.063031  , 13.38885   ]], dtype=float32), 'adaptersfeature_standUMAP220.2euclidean': array([[10.775826 ,  0.7216111],
#        [17.656557 , -5.530971 ],
#        [ 6.788407 ,  9.505705 ],
#        ...,
#        [11.244502 ,  3.0837157],
#        [-1.3248333, 13.853571 ],
#        [ 3.789132 , 14.592397 ]], dtype=float32), 'adaptersfeature_standUMAP220.2manhattan': array([[ 0.33866206, -0.63949996],
#        [ 2.3257253 , -9.534985  ],
#        [10.57967   ,  7.5829563 ],
#        ...,
#        [-0.1737009 , -0.79646796],
#        [ 1.3917426 , 14.209477  ],
#        [13.754183  ,  8.900106  ]], dtype=float32), 'adaptersfeature_standUMAP220.2cosine': array([[-2.841313  , -0.12855445],
#        [ 0.82325405, 16.82425   ],
#        [ 6.4037967 , 16.897467  ],
#        ...,
#        [13.789348  ,  0.04272221],
#        [16.877861  ,  7.1063857 ],
#        [ 5.9665494 , 17.043308  ]], dtype=float32), 'adaptersfeature_standUMAP220.3euclidean': array([[ 5.214946  ,  0.12763412],
#        [22.352123  ,  6.529311  ],
#        [19.70649   ,  5.9890723 ],
#        ...,
#        [ 6.7625623 ,  1.7476624 ],
#        [-1.931388  , 13.321524  ],
#        [ 3.0041745 , 13.011845  ]], dtype=float32), 'adaptersfeature_standUMAP220.3manhattan': array([[ 7.8611274 , -1.7893199 ],
#        [-1.9494716 ,  0.56878555],
#        [-4.0702443 , 14.602112  ],
#        ...,
#        [ 7.3860793 , -1.8562257 ],
#        [10.998656  , 10.478609  ],
#        [-1.7163187 , 14.055348  ]], dtype=float32), 'adaptersfeature_standUMAP220.3cosine': array([[-1.4098315, -1.2458988],
#        [-0.19835  , 15.155466 ],
#        [ 5.0484977, 15.255997 ],
#        ...,
#        [17.869959 ,  1.8534476],
#        [16.638546 , 10.022413 ],
#        [ 5.547081 , 14.886041 ]], dtype=float32), 'adaptersfeature_standUMAP220.4euclidean': array([[5.6444387e+00, 5.7873625e-01],
#        [1.8724371e+01, 5.6788435e+00],
#        [1.5861171e+01, 4.5542035e+00],
#        ...,
#        [5.8588686e+00, 1.1747843e+00],
#        [3.4128940e-03, 1.5143249e+01],
#        [3.5938938e+00, 1.5963261e+01]], dtype=float32), 'adaptersfeature_standUMAP220.4manhattan': array([[ 2.9931347 , -0.18441655],
#        [ 9.828351  , -2.6283207 ],
#        [11.550318  , 11.592736  ],
#        ...,
#        [ 2.2796733 , -0.1534321 ],
#        [ 4.2353845 , 17.018698  ],
#        [ 9.632378  , 10.537115  ]], dtype=float32), 'adaptersfeature_standUMAP220.4cosine': array([[ 3.378288 , -1.6519204],
#        [-1.3375239, 17.066078 ],
#        [ 8.173094 , 16.256348 ],
#        ...,
#        [15.8140135, -1.2894058],
#        [16.07733  ,  9.048892 ],
#        [ 7.2523127, 15.406978 ]], dtype=float32), 'adaptersfeature_standUMAP220.5euclidean': array([[ 9.600774 ,  5.5791345],
#        [21.47772  ,  2.8897264],
#        [18.237797 ,  4.523575 ],
#        ...,
#        [ 9.93182  ,  4.086981 ],
#        [ 0.5093076, 11.334043 ],
#        [ 2.5185466, 14.410665 ]], dtype=float32), 'adaptersfeature_standUMAP220.5manhattan': array([[ 1.045156 ,  5.9708548],
#        [10.75261  , 13.366706 ],
#        [10.066329 ,  1.2339655],
#        ...,
#        [ 2.0519314,  6.460032 ],
#        [ 7.664726 , -7.7102675],
#        [12.524675 ,  1.5876935]], dtype=float32), 'adaptersfeature_standUMAP220.5cosine': array([[-3.4954348, -2.2644515],
#        [ 0.0757233, 16.962948 ],
#        [ 5.8963094, 16.623896 ],
#        ...,
#        [17.386456 , -4.46597  ],
#        [17.026306 ,  9.977048 ],
#        [ 5.7871265, 16.250221 ]], dtype=float32), 'adaptersfeature_standUMAP220.6euclidean': array([[ 9.718881  ,  3.9034765 ],
#        [16.543129  ,  7.805841  ],
#        [17.916893  ,  6.496211  ],
#        ...,
#        [ 9.35026   ,  3.3578162 ],
#        [ 0.13198756, 14.523834  ],
#        [ 2.8957539 , 13.290848  ]], dtype=float32), 'adaptersfeature_standUMAP220.6manhattan': array([[ 8.384001  ,  0.3714013 ],
#        [16.85072   ,  2.572543  ],
#        [-5.9259477 , -0.18633859],
#        ...,
#        [ 9.298029  , -0.24417561],
#        [-2.3215392 ,  9.486989  ],
#        [-6.8573575 ,  2.1536245 ]], dtype=float32), 'adaptersfeature_standUMAP220.6cosine': array([[-1.9019655, -1.3828804],
#        [ 0.7018281, 13.06356  ],
#        [ 4.6110716, 16.978762 ],
#        ...,
#        [15.668492 , -2.1295192],
#        [16.923805 ,  9.526438 ],
#        [ 5.3650784, 16.781603 ]], dtype=float32), 'adaptersfeature_standUMAP220.7euclidean': array([[ 9.590451  ,  0.4823868 ],
#        [16.041098  , 10.058055  ],
#        [18.187893  ,  8.43209   ],
#        ...,
#        [ 8.312008  ,  0.6020971 ],
#        [-0.23025209, 15.540795  ],
#        [ 2.9037366 , 12.9291725 ]], dtype=float32), 'adaptersfeature_standUMAP220.7manhattan': array([[ 1.9714965, 10.871984 ],
#        [ 6.218172 ,  2.109453 ],
#        [-8.533468 , -2.4101446],
#        ...,
#        [ 2.9432032, 10.303691 ],
#        [13.724179 , -3.5490363],
#        [-6.268562 , -0.5372991]], dtype=float32), 'adaptersfeature_standUMAP220.7cosine': array([[ 4.278079 ,  1.3229779],
#        [-1.3424988, 13.201491 ],
#        [ 5.6995745, 17.58107  ],
#        ...,
#        [17.802137 , -2.7489312],
#        [16.640163 , 10.977158 ],
#        [ 4.4875684, 16.659296 ]], dtype=float32), 'adaptersfeature_standUMAP220.8euclidean': array([[ 9.71655  ,  4.412601 ],
#        [18.088467 ,  9.017123 ],
#        [21.056057 ,  8.098985 ],
#        ...,
#        [ 8.737973 ,  3.1212933],
#        [-2.0171669, 13.668291 ],
#        [ 2.839123 , 15.498006 ]], dtype=float32), 'adaptersfeature_standUMAP220.8manhattan': array([[-3.1436956e-03,  2.3138793e+00],
#        [ 1.2149219e+01,  3.7806449e+00],
#        [ 1.1610554e+01,  8.5104837e+00],
#        ...,
#        [ 7.0962393e-01,  2.7558537e+00],
#        [-3.5373065e+00,  1.5730536e+01],
#        [ 1.3439184e+01,  1.1678746e+01]], dtype=float32), 'adaptersfeature_standUMAP220.8cosine': array([[-0.87262696, -2.8352475 ],
#        [ 4.029923  , 10.808978  ],
#        [ 3.4041204 , 18.457884  ],
#        ...,
#        [20.30781   ,  1.5637952 ],
#        [16.501532  , 11.299829  ],
#        [ 3.856569  , 17.569952  ]], dtype=float32), 'adaptersfeature_standUMAP220.9euclidean': array([[10.035096  ,  0.6314846 ],
#        [17.263569  , 12.44225   ],
#        [16.062506  , 11.140568  ],
#        ...,
#        [ 8.945465  , -0.33891827],
#        [ 0.51793516, 15.834822  ],
#        [ 3.3785067 , 17.647436  ]], dtype=float32), 'adaptersfeature_standUMAP220.9manhattan': array([[ 6.188237 , 10.837769 ],
#        [ 1.273304 , 16.802858 ],
#        [-6.0167956, -1.7974172],
#        ...,
#        [ 8.012329 ,  9.778127 ],
#        [ 6.1097026, -5.3702292],
#        [-3.4148698, -2.9830112]], dtype=float32), 'adaptersfeature_standUMAP220.9cosine': array([[ 5.6965637 ,  5.3620143 ],
#        [-1.7169423 , 19.292805  ],
#        [ 5.3084116 , 18.82348   ],
#        ...,
#        [20.169552  , -0.48379582],
#        [16.097223  , 10.218456  ],
#        [ 4.6740746 , 16.352459  ]], dtype=float32), 'adaptersfeature_standUMAP230.1euclidean': array([[2.9245067, 4.58389  ],
#        [7.0109897, 2.8567133],
#        [6.5154653, 2.0345824],
#        ...,
#        [5.067746 , 3.3352334],
#        [8.345506 , 4.076071 ],
#        [7.347116 , 3.6404092]], dtype=float32), 'adaptersfeature_standUMAP230.1manhattan': array([[4.7714977, 8.686352 ],
#        [5.783551 , 3.647172 ],
#        [6.173649 , 8.507575 ],
#        ...,
#        [5.663272 , 4.3310785],
#        [7.8642797, 7.3719044],
#        [6.6264086, 7.584561 ]], dtype=float32), 'adaptersfeature_standUMAP230.1cosine': array([[2.9745824, 6.218784 ],
#        [5.1987267, 3.1228423],
#        [9.260607 , 4.2155333],
#        ...,
#        [8.893317 , 7.678107 ],
#        [9.662522 , 6.382276 ],
#        [8.154201 , 4.516562 ]], dtype=float32), 'adaptersfeature_standUMAP230.2euclidean': array([[5.3411403, 1.0744222],
#        [7.333631 , 2.3740072],
#        [7.637846 , 5.556547 ],
#        ...,
#        [6.8086104, 2.9950624],
#        [9.64313  , 4.353453 ],
#        [8.589173 , 4.037005 ]], dtype=float32), 'adaptersfeature_standUMAP230.2manhattan': array([[ 3.0294657, -1.6469373],
#        [ 6.4378653,  2.9121547],
#        [ 4.954977 , -2.1624095],
#        ...,
#        [ 4.992816 ,  1.4125149],
#        [ 7.061415 , -1.2876867],
#        [ 5.8117814, -1.3010199]], dtype=float32), 'adaptersfeature_standUMAP230.2cosine': array([[2.4743826, 5.0718713],
#        [5.384682 , 1.9898466],
#        [9.472978 , 3.157393 ],
#        ...,
#        [8.370989 , 7.6193905],
#        [9.859126 , 5.920466 ],
#        [7.8482656, 3.8149366]], dtype=float32), 'adaptersfeature_standUMAP230.3euclidean': array([[4.7159324, 0.4695413],
#        [7.4164796, 4.090353 ],
#        [6.3886695, 4.2426023],
#        ...,
#        [5.758514 , 3.6502888],
#        [8.735209 , 4.9811807],
#        [7.4152894, 4.275267 ]], dtype=float32), 'adaptersfeature_standUMAP230.3manhattan': array([[5.812046 , 5.31359  ],
#        [6.94309  , 4.062877 ],
#        [6.7434945, 8.817439 ],
#        ...,
#        [6.3063903, 4.4215617],
#        [8.773732 , 7.827892 ],
#        [7.6212296, 8.298539 ]], dtype=float32), 'adaptersfeature_standUMAP230.3cosine': array([[2.3439791, 6.2879953],
#        [4.311538 , 2.8086233],
#        [8.090874 , 4.112407 ],
#        ...,
#        [8.570913 , 7.8561893],
#        [9.466837 , 6.008114 ],
#        [7.5930257, 3.9655795]], dtype=float32), 'adaptersfeature_standUMAP230.4euclidean': array([[ 5.009886  ,  4.7335258 ],
#        [ 4.5167327 , -1.2641978 ],
#        [ 5.955151  , -0.9982578 ],
#        ...,
#        [ 5.7168374 , -0.28141698],
#        [ 9.256924  ,  0.60017556],
#        [ 8.205617  , -0.38619787]], dtype=float32), 'adaptersfeature_standUMAP230.4manhattan': array([[ 5.8811855,  4.0276847],
#        [ 6.9062963,  2.0147593],
#        [ 9.183842 ,  7.8825574],
#        ...,
#        [ 6.7423234,  3.280542 ],
#        [10.133016 ,  6.0277348],
#        [ 8.995388 ,  6.7363806]], dtype=float32), 'adaptersfeature_standUMAP230.4cosine': array([[ 2.4671023,  5.5192065],
#        [ 4.48531  ,  1.763342 ],
#        [ 8.582948 , 10.585459 ],
#        ...,
#        [ 8.166142 ,  7.8915277],
#        [ 9.497892 ,  6.3996515],
#        [ 7.773373 ,  3.7473783]], dtype=float32), 'adaptersfeature_standUMAP230.5euclidean': array([[4.008335 , 1.2963398],
#        [7.398703 , 2.1189525],
#        [8.020617 , 5.566872 ],
#        ...,
#        [6.134179 , 2.9199495],
#        [9.518965 , 4.6854553],
#        [8.67865  , 3.0947704]], dtype=float32), 'adaptersfeature_standUMAP230.5manhattan': array([[5.186183 , 4.9482718],
#        [6.4439735, 3.2265587],
#        [7.2979527, 8.766105 ],
#        ...,
#        [5.6910686, 4.3322935],
#        [9.315414 , 7.614514 ],
#        [8.327023 , 8.306112 ]], dtype=float32), 'adaptersfeature_standUMAP230.5cosine': array([[0.7685019, 6.9899487],
#        [4.314652 , 2.9411628],
#        [7.8111625, 4.096738 ],
#        ...,
#        [7.734016 , 8.17167  ],
#        [9.456744 , 5.941462 ],
#        [7.269889 , 4.2770905]], dtype=float32), 'adaptersfeature_standUMAP230.6euclidean': array([[ 4.1895704,  5.0162535],
#        [ 9.106408 ,  6.621973 ],
#        [ 8.053555 ,  7.491162 ],
#        ...,
#        [ 6.8298516,  6.703026 ],
#        [10.345038 ,  8.536355 ],
#        [ 8.787508 ,  7.3490977]], dtype=float32), 'adaptersfeature_standUMAP230.6manhattan': array([[ 4.2460012,  7.2340703],
#        [ 5.8916554,  5.5547976],
#        [ 6.0819116,  9.11968  ],
#        ...,
#        [ 4.5500197,  6.300461 ],
#        [ 7.097714 , 10.855859 ],
#        [ 5.846841 , 10.758675 ]], dtype=float32), 'adaptersfeature_standUMAP230.6cosine': array([[ 0.2849824,  5.905    ],
#        [ 3.032865 ,  1.0967124],
#        [ 8.248522 , 10.643255 ],
#        ...,
#        [ 7.3239903,  7.7754283],
#        [ 9.891787 ,  5.845928 ],
#        [ 6.9700494,  3.2943904]], dtype=float32), 'adaptersfeature_standUMAP230.7euclidean': array([[2.9067514 , 2.073167  ],
#        [7.940459  , 7.218961  ],
#        [7.536536  , 0.85477436],
#        ...,
#        [6.2386107 , 5.196582  ],
#        [9.532146  , 4.878783  ],
#        [7.7575192 , 6.088408  ]], dtype=float32), 'adaptersfeature_standUMAP230.7manhattan': array([[5.5465465, 7.9598002],
#        [6.887775 , 1.2043709],
#        [8.038966 , 8.290705 ],
#        ...,
#        [5.7461467, 3.5966923],
#        [9.7163   , 6.117887 ],
#        [8.669176 , 6.7711415]], dtype=float32), 'adaptersfeature_standUMAP230.7cosine': array([[ 0.42131814,  4.21307   ],
#        [ 3.4571517 , -0.44537798],
#        [ 8.831283  ,  0.63358736],
#        ...,
#        [ 7.8115325 ,  7.398026  ],
#        [ 9.932388  ,  4.7323623 ],
#        [ 7.0142307 ,  2.424829  ]], dtype=float32), 'adaptersfeature_standUMAP230.8euclidean': array([[ 4.1105127 ,  0.06260656],
#        [ 8.265724  ,  7.005119  ],
#        [ 7.6198983 ,  3.2074459 ],
#        ...,
#        [ 5.8884306 ,  4.64197   ],
#        [10.535021  ,  5.3791227 ],
#        [ 8.299784  ,  5.6993704 ]], dtype=float32), 'adaptersfeature_standUMAP230.8manhattan': array([[2.298014 , 8.475189 ],
#        [5.879074 , 2.1144738],
#        [6.090063 , 6.130429 ],
#        ...,
#        [4.095259 , 3.9564223],
#        [6.720883 , 8.312373 ],
#        [5.535138 , 8.523042 ]], dtype=float32), 'adaptersfeature_standUMAP230.8cosine': array([[-1.3189745 ,  6.218048  ],
#        [ 2.2956338 ,  0.08024812],
#        [ 8.262821  , 10.96674   ],
#        ...,
#        [ 6.608355  ,  8.189006  ],
#        [ 8.733876  ,  5.672073  ],
#        [ 6.957806  ,  2.7322125 ]], dtype=float32), 'adaptersfeature_standUMAP230.9euclidean': array([[ 5.505156 ,  2.4398816],
#        [10.9598055,  4.111423 ],
#        [ 9.556713 ,  3.0782614],
#        ...,
#        [ 7.9452395,  4.102843 ],
#        [12.056182 ,  6.521475 ],
#        [10.562083 ,  4.727143 ]], dtype=float32), 'adaptersfeature_standUMAP230.9manhattan': array([[ 5.4511576,  3.5013258],
#        [ 7.338388 ,  1.2412542],
#        [ 8.755043 ,  8.91156  ],
#        ...,
#        [ 6.2303677,  3.526381 ],
#        [10.229909 ,  7.179687 ],
#        [ 9.524747 ,  6.39345  ]], dtype=float32), 'adaptersfeature_standUMAP230.9cosine': array([[-0.2864154,  6.1546435],
#        [ 3.959556 ,  1.6683226],
#        [ 9.895985 , 10.949023 ],
#        ...,
#        [ 7.869496 ,  8.069922 ],
#        [ 9.399846 ,  5.2275743],
#        [ 7.055899 ,  3.538733 ]], dtype=float32), 'adaptersfeature_standUMAP240.1euclidean': array([[4.994646  , 6.122659  ],
#        [2.0648324 , 6.392388  ],
#        [2.7076254 , 6.7158184 ],
#        ...,
#        [2.683982  , 8.239264  ],
#        [0.89986587, 8.8608055 ],
#        [1.4238511 , 8.7435055 ]], dtype=float32), 'adaptersfeature_standUMAP240.1manhattan': array([[4.4671464, 6.327265 ],
#        [5.5536547, 6.4408774],
#        [7.609652 , 6.646536 ],
#        ...,
#        [4.953522 , 9.227687 ],
#        [7.502711 , 9.33537  ],
#        [6.641006 , 9.514614 ]], dtype=float32), 'adaptersfeature_standUMAP240.1cosine': array([[1.8810441, 5.4236903],
#        [3.4107776, 2.2064643],
#        [6.850358 , 3.0182683],
#        ...,
#        [7.2796407, 6.150072 ],
#        [8.371168 , 5.015802 ],
#        [6.916348 , 3.3415241]], dtype=float32), 'adaptersfeature_standUMAP240.2euclidean': array([[ 4.9063835 ,  7.1004534 ],
#        [ 2.8275013 ,  7.0741773 ],
#        [ 2.7830627 ,  7.695315  ],
#        ...,
#        [ 2.7486649 ,  8.845227  ],
#        [ 0.93194175, 10.232522  ],
#        [ 1.7394292 , 10.129093  ]], dtype=float32), 'adaptersfeature_standUMAP240.2manhattan': array([[ 5.2502203,  1.94836  ],
#        [ 6.2832   ,  1.9472138],
#        [ 8.8804245,  1.9196124],
#        ...,
#        [ 6.557731 , -1.2232836],
#        [ 9.054287 , -0.7476625],
#        [ 8.110801 , -1.2614157]], dtype=float32), 'adaptersfeature_standUMAP240.2cosine': array([[2.3777149, 6.3114223],
#        [4.355774 , 3.0427139],
#        [6.788768 , 5.1033607],
#        ...,
#        [7.2614803, 7.8523726],
#        [8.470875 , 6.41103  ],
#        [7.067436 , 4.5581284]], dtype=float32), 'adaptersfeature_standUMAP240.3euclidean': array([[4.4552436, 6.0775247],
#        [2.804582 , 5.7342696],
#        [2.254451 , 6.4989448],
#        ...,
#        [3.4552655, 8.0539   ],
#        [0.6936   , 9.412409 ],
#        [1.1106395, 8.822778 ]], dtype=float32), 'adaptersfeature_standUMAP240.3manhattan': array([[ 3.8335357,  6.1393485],
#        [ 4.9156203,  6.49274  ],
#        [ 6.9027867,  8.457331 ],
#        ...,
#        [ 3.6420782,  8.615374 ],
#        [ 5.8565316, 10.956382 ],
#        [ 4.686923 , 10.51091  ]], dtype=float32), 'adaptersfeature_standUMAP240.3cosine': array([[2.9320104, 6.4858074],
#        [3.936073 , 2.9674065],
#        [7.3639607, 3.6402702],
#        ...,
#        [9.081835 , 7.037525 ],
#        [9.232048 , 4.8841786],
#        [7.878914 , 2.6045303]], dtype=float32), 'adaptersfeature_standUMAP240.4euclidean': array([[ 2.7166908 ,  9.047626  ],
#        [ 0.68466395,  8.554519  ],
#        [ 1.6168061 ,  4.8300495 ],
#        ...,
#        [ 2.0121667 ,  7.813978  ],
#        [-0.5005468 ,  6.511409  ],
#        [ 0.19936351,  7.6807723 ]], dtype=float32), 'adaptersfeature_standUMAP240.4manhattan': array([[ 4.161768 ,  1.3568673],
#        [ 5.3692145,  2.157604 ],
#        [ 7.560224 ,  1.6124548],
#        ...,
#        [ 5.2811813, -1.0373881],
#        [ 8.544172 , -1.1610552],
#        [ 7.642204 , -1.6586418]], dtype=float32), 'adaptersfeature_standUMAP240.4cosine': array([[2.2000642, 5.3660088],
#        [5.8781247, 2.45754  ],
#        [7.620435 , 5.499389 ],
#        ...,
#        [7.821581 , 9.151207 ],
#        [9.377538 , 7.2164855],
#        [8.51938  , 5.098097 ]], dtype=float32), 'adaptersfeature_standUMAP240.5euclidean': array([[ 4.1567197,  6.561671 ],
#        [ 1.8121784,  5.5861425],
#        [ 1.1494263,  5.4592752],
#        ...,
#        [ 2.312549 ,  9.923606 ],
#        [-1.4634573,  9.298341 ],
#        [-0.3596452,  8.670749 ]], dtype=float32), 'adaptersfeature_standUMAP240.5manhattan': array([[ 5.9637613,  6.9452143],
#        [ 7.2895484,  7.0896716],
#        [ 9.675998 ,  8.89626  ],
#        ...,
#        [ 6.8672056, 10.164163 ],
#        [ 9.6161   , 11.358247 ],
#        [ 8.531294 , 11.22058  ]], dtype=float32), 'adaptersfeature_standUMAP240.5cosine': array([[2.468492 , 6.6906605],
#        [5.0610337, 2.9336395],
#        [8.262599 , 6.720209 ],
#        ...,
#        [8.047879 , 9.460759 ],
#        [9.579722 , 8.102857 ],
#        [8.432253 , 5.61383  ]], dtype=float32), 'adaptersfeature_standUMAP240.6euclidean': array([[ 4.659695  ,  5.755495  ],
#        [ 1.8181663 ,  5.6809406 ],
#        [ 1.5665216 ,  6.0270867 ],
#        ...,
#        [ 2.267747  ,  8.482723  ],
#        [ 0.10215379, 10.512582  ],
#        [ 0.271279  ,  9.479777  ]], dtype=float32), 'adaptersfeature_standUMAP240.6manhattan': array([[ 4.356534 ,  6.46565  ],
#        [ 6.222558 ,  6.2292624],
#        [ 8.393519 ,  8.381287 ],
#        ...,
#        [ 5.2245173,  9.249459 ],
#        [ 6.7568936, 11.183518 ],
#        [ 6.6387067, 10.742253 ]], dtype=float32), 'adaptersfeature_standUMAP240.6cosine': array([[0.92263186, 6.4640174 ],
#        [3.2771788 , 1.6498778 ],
#        [6.556716  , 5.122971  ],
#        ...,
#        [7.117341  , 7.425067  ],
#        [9.381371  , 5.795989  ],
#        [6.9517827 , 3.0432124 ]], dtype=float32), 'adaptersfeature_standUMAP240.7euclidean': array([[ 5.3459573,  1.9877194],
#        [ 2.116843 ,  2.7172508],
#        [ 2.6299527,  2.51215  ],
#        ...,
#        [ 3.6571364, -0.7098754],
#        [ 1.1998205, -2.1969662],
#        [ 1.245445 , -1.2635624]], dtype=float32), 'adaptersfeature_standUMAP240.7manhattan': array([[ 3.322241 ,  8.367314 ],
#        [ 4.7942057,  8.309457 ],
#        [ 7.2500873, 10.472313 ],
#        ...,
#        [ 4.1491666, 12.799178 ],
#        [ 7.1619854, 13.068849 ],
#        [ 6.1572003, 12.999091 ]], dtype=float32), 'adaptersfeature_standUMAP240.7cosine': array([[0.07503967, 5.641948  ],
#        [2.100831  , 0.73587084],
#        [6.1543975 , 2.200926  ],
#        ...,
#        [8.046295  , 7.134303  ],
#        [8.179821  , 4.872813  ],
#        [6.3431864 , 1.9645859 ]], dtype=float32), 'adaptersfeature_standUMAP240.8euclidean': array([[ 6.738605 ,  5.9883356],
#        [ 4.7024307,  5.65369  ],
#        [ 4.4431696,  6.9261875],
#        ...,
#        [ 6.1015444,  8.24779  ],
#        [ 4.4610395, 11.986761 ],
#        [ 4.490066 , 10.103111 ]], dtype=float32), 'adaptersfeature_standUMAP240.8manhattan': array([[ 6.047945 ,  5.2437134],
#        [ 7.259125 ,  4.489692 ],
#        [ 9.688778 ,  5.092078 ],
#        ...,
#        [ 8.182923 ,  9.429809 ],
#        [10.777903 ,  9.048674 ],
#        [10.399669 ,  9.193977 ]], dtype=float32), 'adaptersfeature_standUMAP240.8cosine': array([[0.66016126, 5.697392  ],
#        [3.9258919 , 1.6467954 ],
#        [6.5481625 , 5.2334857 ],
#        ...,
#        [7.138525  , 8.339057  ],
#        [9.208066  , 6.416019  ],
#        [7.6436214 , 2.8231726 ]], dtype=float32), 'adaptersfeature_standUMAP240.9euclidean': array([[5.154635  , 8.463783  ],
#        [1.7245243 , 8.951639  ],
#        [1.6185708 , 6.6909313 ],
#        ...,
#        [2.3349206 , 7.1505046 ],
#        [0.15215793, 6.5150895 ],
#        [0.65976256, 7.174873  ]], dtype=float32), 'adaptersfeature_standUMAP240.9manhattan': array([[ 4.7565536, -1.4008776],
#        [ 5.6877885, -0.3583071],
#        [ 8.432132 , -2.662819 ],
#        ...,
#        [ 5.838533 , -3.6304264],
#        [ 9.312702 , -5.9095354],
#        [ 7.8133407, -5.718588 ]], dtype=float32), 'adaptersfeature_standUMAP240.9cosine': array([[ 0.31056672,  6.312604  ],
#        [ 4.1745715 ,  2.8223042 ],
#        [ 8.024693  ,  3.9822176 ],
#        ...,
#        [ 7.565051  ,  8.34671   ],
#        [10.547919  ,  6.3994565 ],
#        [ 7.4804997 ,  3.0746005 ]], dtype=float32), 'adaptersfeature_standUMAP250.1euclidean': array([[5.26683  , 4.9191437],
#        [7.7860627, 4.871741 ],
#        [7.795118 , 5.4478674],
#        ...,
#        [6.744083 , 6.255929 ],
#        [9.373407 , 7.780993 ],
#        [8.574885 , 7.356192 ]], dtype=float32), 'adaptersfeature_standUMAP250.1manhattan': array([[ 5.9088206,  0.6336261],
#        [ 7.032413 ,  0.7241212],
#        [ 8.156261 ,  0.9886368],
#        ...,
#        [ 6.353223 , -0.989883 ],
#        [ 9.186456 , -1.6214771],
#        [ 8.395345 , -1.6671853]], dtype=float32), 'adaptersfeature_standUMAP250.1cosine': array([[3.9195373, 6.108555 ],
#        [5.3937488, 3.2900472],
#        [8.782793 , 3.221395 ],
#        ...,
#        [9.25423  , 7.2087545],
#        [9.718897 , 5.4499745],
#        [8.480804 , 3.7704031]], dtype=float32), 'adaptersfeature_standUMAP250.2euclidean': array([[ 5.1875014,  6.5066605],
#        [ 6.925404 ,  8.286467 ],
#        [ 6.8892627,  7.739332 ],
#        ...,
#        [ 4.981984 ,  9.249742 ],
#        [ 6.859791 , 11.094599 ],
#        [ 6.6050024, 10.343095 ]], dtype=float32), 'adaptersfeature_standUMAP250.2manhattan': array([[4.4585414, 5.399433 ],
#        [5.9657884, 5.756858 ],
#        [6.9055085, 6.1024847],
#        ...,
#        [5.1027527, 7.7423797],
#        [7.823276 , 8.639029 ],
#        [6.7436275, 8.734952 ]], dtype=float32), 'adaptersfeature_standUMAP250.2cosine': array([[2.7491474, 6.9853473],
#        [5.74985  , 4.656486 ],
#        [7.9340825, 6.7196946],
#        ...,
#        [7.817265 , 9.474298 ],
#        [9.028516 , 7.977859 ],
#        [8.154386 , 5.8821363]], dtype=float32), 'adaptersfeature_standUMAP250.3euclidean': array([[ 5.033836,  9.518011],
#        [ 7.688374,  9.049482],
#        [ 7.106126,  9.446834],
#        ...,
#        [ 6.848667, 12.011567],
#        [ 9.625781, 11.992353],
#        [ 8.754168, 11.578568]], dtype=float32), 'adaptersfeature_standUMAP250.3manhattan': array([[ 4.0908256,  9.983748 ],
#        [ 5.4719505,  9.727623 ],
#        [ 7.0319533, 10.675233 ],
#        ...,
#        [ 4.9951396, 13.29269  ],
#        [ 7.1751914, 12.860144 ],
#        [ 6.401379 , 13.317971 ]], dtype=float32), 'adaptersfeature_standUMAP250.3cosine': array([[2.6728756, 6.011214 ],
#        [4.2265105, 3.2488418],
#        [7.712075 , 4.192382 ],
#        ...,
#        [8.170769 , 7.0638924],
#        [8.980181 , 5.248885 ],
#        [7.40784  , 3.3739364]], dtype=float32), 'adaptersfeature_standUMAP250.4euclidean': array([[ 5.452384 ,  7.355662 ],
#        [ 7.069635 ,  7.22417  ],
#        [ 7.010269 ,  7.7922516],
#        ...,
#        [ 6.6022243,  9.333987 ],
#        [ 9.535679 , 10.513797 ],
#        [ 8.840939 , 10.00403  ]], dtype=float32), 'adaptersfeature_standUMAP250.4manhattan': array([[ 4.4677463,  6.8671203],
#        [ 6.1505246,  6.7960668],
#        [ 7.568968 ,  7.2035956],
#        ...,
#        [ 5.956293 , 10.46164  ],
#        [ 8.766843 , 10.081771 ],
#        [ 7.439552 , 10.209413 ]], dtype=float32), 'adaptersfeature_standUMAP250.4cosine': array([[3.5278485, 6.044396 ],
#        [6.3173013, 3.6052938],
#        [8.694444 , 6.0506887],
#        ...,
#        [8.46618  , 8.685303 ],
#        [9.75514  , 7.25472  ],
#        [8.92008  , 4.9287877]], dtype=float32), 'adaptersfeature_standUMAP250.5euclidean': array([[ 9.151274 ,  8.091055 ],
#        [10.837163 ,  6.218835 ],
#        [10.10008  ,  6.9402075],
#        ...,
#        [11.524136 ,  8.806479 ],
#        [14.61837  ,  7.0080414],
#        [13.122011 ,  7.6603303]], dtype=float32), 'adaptersfeature_standUMAP250.5manhattan': array([[5.289918 , 5.329789 ],
#        [7.030211 , 5.0904226],
#        [9.156697 , 5.864952 ],
#        ...,
#        [7.396099 , 9.199071 ],
#        [9.63594  , 7.8567514],
#        [8.925508 , 8.337297 ]], dtype=float32), 'adaptersfeature_standUMAP250.5cosine': array([[1.9778773, 4.7126226],
#        [4.3289585, 1.7013079],
#        [7.5988073, 4.0348654],
#        ...,
#        [7.767493 , 6.781489 ],
#        [9.386788 , 4.5148435],
#        [7.685719 , 2.2749841]], dtype=float32), 'adaptersfeature_standUMAP250.6euclidean': array([[ 6.9403734 ,  4.130496  ],
#        [ 9.715927  ,  3.9662738 ],
#        [ 9.21557   ,  3.6399977 ],
#        ...,
#        [ 8.572781  ,  1.3832532 ],
#        [12.152506  ,  0.51150644],
#        [11.098259  ,  1.138755  ]], dtype=float32), 'adaptersfeature_standUMAP250.6manhattan': array([[ 5.7998824,  8.814935 ],
#        [ 7.4867363,  8.629337 ],
#        [ 9.089134 ,  9.979557 ],
#        ...,
#        [ 6.046766 , 12.995348 ],
#        [ 9.575186 , 13.522703 ],
#        [ 8.510865 , 13.485617 ]], dtype=float32), 'adaptersfeature_standUMAP250.6cosine': array([[ 2.7902277,  5.7001424],
#        [ 5.813841 ,  3.146193 ],
#        [ 8.828143 ,  5.176935 ],
#        ...,
#        [ 9.077303 ,  8.441929 ],
#        [10.602796 ,  5.9793034],
#        [ 8.738559 ,  3.205189 ]], dtype=float32), 'adaptersfeature_standUMAP250.7euclidean': array([[ 4.76211 ,  8.929648],
#        [ 8.938942,  8.454187],
#        [ 7.650436,  9.394509],
#        ...,
#        [ 7.279065, 11.594231],
#        [10.379055, 13.061648],
#        [ 9.463876, 11.560494]], dtype=float32), 'adaptersfeature_standUMAP250.7manhattan': array([[ 5.1980968 , -1.1175191 ],
#        [ 6.5795217 , -0.59005636],
#        [ 8.48348   , -0.3008837 ],
#        ...,
#        [ 7.665364  , -3.7100828 ],
#        [10.853993  , -3.7029655 ],
#        [ 9.863651  , -3.703897  ]], dtype=float32), 'adaptersfeature_standUMAP250.7cosine': array([[ 2.687481 ,  6.2303443],
#        [ 5.976146 ,  2.9721096],
#        [ 8.859103 ,  5.1804113],
#        ...,
#        [ 9.07329  ,  9.006642 ],
#        [10.990318 ,  6.5169697],
#        [ 8.613502 ,  3.8327668]], dtype=float32), 'adaptersfeature_standUMAP250.8euclidean': array([[ 4.896734 ,  6.3490763],
#        [ 7.7095103,  7.040502 ],
#        [ 7.243507 ,  7.7125654],
#        ...,
#        [ 5.2175703,  9.811657 ],
#        [ 7.6987295, 12.524678 ],
#        [ 7.0344434, 10.654653 ]], dtype=float32), 'adaptersfeature_standUMAP250.8manhattan': array([[ 6.323489,  8.981197],
#        [ 8.060767,  9.112811],
#        [ 9.34212 ,  8.766179],
#        ...,
#        [ 8.074028, 11.664945],
#        [11.516964, 12.221082],
#        [10.554715, 13.266925]], dtype=float32), 'adaptersfeature_standUMAP250.8cosine': array([[2.5241377, 7.5669565],
#        [3.9316165, 3.2598655],
#        [8.333705 , 5.922641 ],
#        ...,
#        [8.870245 , 7.58475  ],
#        [9.828839 , 5.129141 ],
#        [7.2876043, 2.7818542]], dtype=float32), 'adaptersfeature_standUMAP250.9euclidean': array([[ 7.20743  ,  3.9856203],
#        [ 9.214695 ,  7.278248 ],
#        [ 9.27098  ,  6.1802135],
#        ...,
#        [11.296651 ,  3.680284 ],
#        [14.591505 ,  5.4185157],
#        [12.394977 ,  5.3277497]], dtype=float32), 'adaptersfeature_standUMAP250.9manhattan': array([[ 5.44637  ,  5.165165 ],
#        [ 7.2080474,  4.2263093],
#        [ 9.849807 ,  4.6270456],
#        ...,
#        [ 6.926192 ,  8.292731 ],
#        [10.651808 ,  8.727827 ],
#        [ 9.404926 ,  8.341126 ]], dtype=float32), 'adaptersfeature_standUMAP250.9cosine': array([[ 2.9584157,  6.5621114],
#        [ 7.385484 ,  3.2171934],
#        [10.270781 ,  7.201543 ],
#        ...,
#        [ 9.575612 , 10.361657 ],
#        [11.972013 ,  8.348945 ],
#        [10.745703 ,  4.6305184]], dtype=float32), 'adaptersfeature_standUMAP260.1euclidean': array([[ 2.1968665e+00,  4.8520112e+00],
#        [-9.3461223e-02,  3.2257464e+00],
#        [ 3.7294081e-01,  3.8356175e+00],
#        ...,
#        [ 2.6724413e-03,  6.0512543e+00],
#        [-2.2617841e+00,  5.0110626e+00],
#        [-1.6928115e+00,  5.0201354e+00]], dtype=float32), 'adaptersfeature_standUMAP260.1manhattan': array([[5.179342 , 7.0047865],
#        [6.497034 , 6.842583 ],
#        [7.009438 , 7.333878 ],
#        ...,
#        [5.329271 , 9.504903 ],
#        [8.006139 , 9.4707575],
#        [7.107923 , 9.571341 ]], dtype=float32), 'adaptersfeature_standUMAP260.1cosine': array([[3.6014175, 4.0210085],
#        [6.137827 , 5.169001 ],
#        [8.467981 , 3.2014315],
#        ...,
#        [7.7378635, 1.0593823],
#        [9.0554085, 1.9778688],
#        [8.893928 , 4.2254467]], dtype=float32), 'adaptersfeature_standUMAP260.2euclidean': array([[ 2.1977592e+00,  5.7078724e+00],
#        [-6.5761940e-03,  7.2846718e+00],
#        [ 6.4861876e-01,  7.0717630e+00],
#        ...,
#        [-5.1640838e-01,  4.7848439e+00],
#        [-2.5227387e+00,  5.5557508e+00],
#        [-1.2942334e+00,  5.6496816e+00]], dtype=float32), 'adaptersfeature_standUMAP260.2manhattan': array([[ 6.801991  ,  0.85407686],
#        [ 7.978309  ,  0.7379617 ],
#        [ 8.936002  ,  0.65967107],
#        ...,
#        [ 7.314572  , -1.9328996 ],
#        [ 9.899051  , -1.9567115 ],
#        [ 8.883888  , -2.1565611 ]], dtype=float32), 'adaptersfeature_standUMAP260.2cosine': array([[3.4010556, 4.730333 ],
#        [5.661784 , 7.761731 ],
#        [8.068621 , 5.710555 ],
#        ...,
#        [8.369111 , 3.186653 ],
#        [8.756334 , 4.8344135],
#        [8.725701 , 6.7010727]], dtype=float32), 'adaptersfeature_standUMAP260.3euclidean': array([[ 5.548966  ,  4.9042234 ],
#        [ 3.4367828 ,  2.8528574 ],
#        [ 3.5816188 ,  3.2091856 ],
#        ...,
#        [ 5.513041  ,  1.5025867 ],
#        [ 4.204986  , -0.34858826],
#        [ 4.33203   ,  0.62326115]], dtype=float32), 'adaptersfeature_standUMAP260.3manhattan': array([[ 4.9066696,  1.1932732],
#        [ 6.404311 ,  1.7741565],
#        [ 7.5723195,  1.1088257],
#        ...,
#        [ 6.100317 , -1.6175953],
#        [ 8.689439 , -1.153038 ],
#        [ 7.783029 , -1.3886492]], dtype=float32), 'adaptersfeature_standUMAP260.3cosine': array([[3.4625487 , 2.709872  ],
#        [5.5366254 , 5.2013335 ],
#        [8.464366  , 3.6801493 ],
#        ...,
#        [8.54042   , 0.63420576],
#        [9.51533   , 2.3115997 ],
#        [8.634312  , 4.477061  ]], dtype=float32), 'adaptersfeature_standUMAP260.4euclidean': array([[ 2.3735824 ,  0.70646507],
#        [-0.15684773,  2.714074  ],
#        [ 0.45941618,  1.9703349 ],
#        ...,
#        [-0.55178726, -1.046304  ],
#        [-3.191543  , -0.27639177],
#        [-2.0136082 , -0.01686812]], dtype=float32), 'adaptersfeature_standUMAP260.4manhattan': array([[7.3997507, 4.9891386],
#        [8.468498 , 4.901183 ],
#        [9.62339  , 5.4161067],
#        ...,
#        [7.6119537, 7.8555284],
#        [9.692499 , 8.779319 ],
#        [8.941556 , 8.592409 ]], dtype=float32), 'adaptersfeature_standUMAP260.4cosine': array([[ 5.047358 ,  4.893229 ],
#        [ 7.8449554,  7.231245 ],
#        [12.311796 ,  6.4221826],
#        ...,
#        [10.578604 ,  2.3301272],
#        [11.017349 ,  4.2259183],
#        [10.828328 ,  6.571014 ]], dtype=float32), 'adaptersfeature_standUMAP260.5euclidean': array([[ 4.215503 ,  3.056821 ],
#        [ 0.9158083,  3.1874702],
#        [ 1.6299422,  2.9410086],
#        ...,
#        [ 1.7180488,  1.1903297],
#        [-0.5741876, -0.3549713],
#        [ 0.481217 ,  0.8644584]], dtype=float32), 'adaptersfeature_standUMAP260.5manhattan': array([[ 4.031261  ,  0.11736513],
#        [ 5.766123  , -1.0050138 ],
#        [ 6.6159215 , -2.0209389 ],
#        ...,
#        [ 3.6306767 , -3.6659644 ],
#        [ 6.7177567 , -4.9750814 ],
#        [ 5.6329465 , -4.718427  ]], dtype=float32), 'adaptersfeature_standUMAP260.5cosine': array([[3.0253482, 3.9608426],
#        [5.5352726, 6.73771  ],
#        [7.8654866, 4.500985 ],
#        ...,
#        [8.739998 , 1.3986703],
#        [8.962134 , 3.8346236],
#        [8.693283 , 5.8873963]], dtype=float32), 'adaptersfeature_standUMAP260.6euclidean': array([[ 4.0828857 ,  0.8107001 ],
#        [ 0.56724423,  1.1190337 ],
#        [ 1.2131201 ,  1.2998317 ],
#        ...,
#        [ 1.664946  , -1.5163692 ],
#        [-0.5860681 , -2.1155746 ],
#        [ 0.14943227, -1.4157444 ]], dtype=float32), 'adaptersfeature_standUMAP260.6manhattan': array([[ 2.0852869, -0.4612921],
#        [ 3.8917162, -0.6031686],
#        [ 5.1952662, -1.3579259],
#        ...,
#        [ 2.0892718, -4.4335837],
#        [ 5.9539194, -4.803151 ],
#        [ 4.3146634, -4.623931 ]], dtype=float32), 'adaptersfeature_standUMAP260.6cosine': array([[3.243792 , 5.237001 ],
#        [6.599085 , 7.986293 ],
#        [8.521407 , 4.231092 ],
#        ...,
#        [8.539752 , 1.2477261],
#        [9.54188  , 3.617814 ],
#        [8.957629 , 5.6967225]], dtype=float32), 'adaptersfeature_standUMAP260.7euclidean': array([[ 0.5447398 ,  2.8967495 ],
#        [-0.71211666,  0.70776236],
#        [-1.3833063 ,  1.3847151 ],
#        ...,
#        [-2.1675708 ,  2.9060245 ],
#        [-5.6345205 ,  1.9156046 ],
#        [-3.561201  ,  1.9846908 ]], dtype=float32), 'adaptersfeature_standUMAP260.7manhattan': array([[ 5.8320165, -4.422652 ],
#        [ 7.5621843, -3.926369 ],
#        [ 9.205377 , -4.548954 ],
#        ...,
#        [ 7.142842 , -7.7680984],
#        [10.361722 , -7.5523396],
#        [ 9.186182 , -7.156952 ]], dtype=float32), 'adaptersfeature_standUMAP260.7cosine': array([[ 4.8338876,  2.6337006],
#        [ 6.427117 ,  7.1506376],
#        [ 9.977465 ,  5.276658 ],
#        ...,
#        [11.380984 ,  2.5206802],
#        [11.055883 ,  4.9474344],
#        [ 9.57862  ,  7.2058945]], dtype=float32), 'adaptersfeature_standUMAP260.8euclidean': array([[ 4.306509  ,  4.0493903 ],
#        [ 1.3389032 ,  6.1074004 ],
#        [ 1.8278514 ,  4.7415843 ],
#        ...,
#        [ 0.7037303 ,  1.6789676 ],
#        [-1.3557416 ,  1.4229738 ],
#        [-0.60538304,  3.0104144 ]], dtype=float32), 'adaptersfeature_standUMAP260.8manhattan': array([[ 4.95166  , 12.1091795],
#        [ 6.906068 , 11.814477 ],
#        [ 8.522951 , 12.446325 ],
#        ...,
#        [ 5.056836 , 15.747423 ],
#        [ 8.797866 , 16.895979 ],
#        [ 7.867935 , 15.621226 ]], dtype=float32), 'adaptersfeature_standUMAP260.8cosine': array([[2.0741882 , 4.098417  ],
#        [4.7982073 , 7.2243567 ],
#        [8.327835  , 3.905541  ],
#        ...,
#        [8.893302  , 0.97233945],
#        [9.10519   , 4.1391625 ],
#        [8.184297  , 6.9344053 ]], dtype=float32), 'adaptersfeature_standUMAP260.9euclidean': array([[ 2.6851943,  2.648357 ],
#        [ 0.1272618,  5.9092293],
#        [ 0.6201798,  4.896982 ],
#        ...,
#        [-0.6217547,  1.6900693],
#        [-3.7838943,  2.9201822],
#        [-2.3411274,  3.4973693]], dtype=float32), 'adaptersfeature_standUMAP260.9manhattan': array([[ 5.9063964 , -0.41271904],
#        [ 7.7241116 , -1.0620527 ],
#        [ 9.058739  , -1.5899469 ],
#        ...,
#        [ 6.005234  , -4.593726  ],
#        [ 9.065268  , -5.3320904 ],
#        [ 7.7723703 , -5.546321  ]], dtype=float32), 'adaptersfeature_standUMAP260.9cosine': array([[ 2.7604597,  4.3143616],
#        [ 5.9405637,  8.142124 ],
#        [11.90899  ,  6.764166 ],
#        ...,
#        [ 9.406821 ,  1.1022098],
#        [11.324327 ,  3.908929 ],
#        [ 9.401994 ,  6.546794 ]], dtype=float32), 'adaptersfeature_standUMAP270.1euclidean': array([[ 4.4334116, 10.350018 ],
#        [ 6.755086 ,  8.681624 ],
#        [ 6.9012856,  9.295884 ],
#        ...,
#        [ 6.839378 , 11.479621 ],
#        [ 8.938148 , 10.956409 ],
#        [ 8.091073 , 11.092276 ]], dtype=float32), 'adaptersfeature_standUMAP270.1manhattan': array([[ 5.649275 , -2.1583004],
#        [ 7.3592496, -2.3533366],
#        [ 7.7323136, -2.2924526],
#        ...,
#        [ 6.9371467, -4.1849427],
#        [ 8.969726 , -4.4225764],
#        [ 8.020355 , -4.4442534]], dtype=float32), 'adaptersfeature_standUMAP270.1cosine': array([[ 5.4160714,  2.9445407],
#        [ 6.8391333,  5.8718433],
#        [ 9.774321 ,  4.7006626],
#        ...,
#        [11.041795 ,  2.1566076],
#        [10.43433  ,  3.7823305],
#        [ 9.911998 ,  5.4304566]], dtype=float32), 'adaptersfeature_standUMAP270.2euclidean': array([[ 2.3331497 ,  6.0183754 ],
#        [-0.37925947,  4.8890276 ],
#        [-0.19043405,  5.212611  ],
#        ...,
#        [ 0.07234649,  7.359715  ],
#        [-2.2858508 ,  7.037499  ],
#        [-1.1724478 ,  6.592262  ]], dtype=float32), 'adaptersfeature_standUMAP270.2manhattan': array([[ 4.099218  , -0.24254373],
#        [ 5.6519575 , -0.30483842],
#        [ 6.457426  , -1.0305904 ],
#        ...,
#        [ 5.1326456 , -3.2500024 ],
#        [ 7.511224  , -3.4305334 ],
#        [ 6.6057296 , -3.2274745 ]], dtype=float32), 'adaptersfeature_standUMAP270.2cosine': array([[2.7322948, 3.638651 ],
#        [3.5451586, 6.795505 ],
#        [7.073027 , 4.6773276],
#        ...,
#        [8.125824 , 3.0425415],
#        [7.6884203, 4.9898005],
#        [7.003    , 6.4399867]], dtype=float32), 'adaptersfeature_standUMAP270.3euclidean': array([[ 3.83964   ,  1.4330826 ],
#        [ 1.1679847 ,  3.3636222 ],
#        [ 1.2309934 ,  2.512696  ],
#        ...,
#        [ 1.0127496 ,  0.10139747],
#        [-1.3311533 ,  0.46046546],
#        [-0.4746186 ,  0.5627266 ]], dtype=float32), 'adaptersfeature_standUMAP270.3manhattan': array([[ 3.282134 , -1.1912886],
#        [ 4.9646435, -1.8049834],
#        [ 5.425373 , -1.8890744],
#        ...,
#        [ 2.8364308, -4.37534  ],
#        [ 5.2316036, -5.043603 ],
#        [ 4.2404118, -4.6327624]], dtype=float32), 'adaptersfeature_standUMAP270.3cosine': array([[4.4319386, 2.1527517],
#        [6.080172 , 4.919214 ],
#        [9.013215 , 3.5266898],
#        ...,
#        [9.160431 , 0.5846354],
#        [9.589634 , 2.6001115],
#        [9.693529 , 4.5232124]], dtype=float32), 'adaptersfeature_standUMAP270.4euclidean': array([[ 4.8423886,  8.280888 ],
#        [ 2.2844603,  8.843352 ],
#        [ 2.4165869,  9.139307 ],
#        ...,
#        [ 3.978209 , 10.411567 ],
#        [ 2.240116 , 12.200357 ],
#        [ 2.7060568, 11.43112  ]], dtype=float32), 'adaptersfeature_standUMAP270.4manhattan': array([[ 3.8797457 ,  0.3605046 ],
#        [ 5.695168  , -0.91691244],
#        [ 6.1342735 , -1.4258906 ],
#        ...,
#        [ 3.4259956 , -3.3780117 ],
#        [ 5.2292523 , -4.53893   ],
#        [ 4.7286983 , -3.5764015 ]], dtype=float32), 'adaptersfeature_standUMAP270.4cosine': array([[ 4.484791 ,  2.4013896],
#        [ 5.9583344,  5.8512125],
#        [ 9.095913 ,  4.3082676],
#        ...,
#        [10.171263 ,  2.4294221],
#        [10.015929 ,  4.7588677],
#        [ 9.140425 ,  6.770193 ]], dtype=float32), 'adaptersfeature_standUMAP270.5euclidean': array([[ 3.5162623 ,  7.693496  ],
#        [-0.3908076 ,  6.7933927 ],
#        [ 0.43842453,  7.1167245 ],
#        ...,
#        [ 0.29312685, 10.064592  ],
#        [-2.0298665 ,  9.714843  ],
#        [-1.0007647 ,  9.009115  ]], dtype=float32), 'adaptersfeature_standUMAP270.5manhattan': array([[ 4.914807 ,  9.676173 ],
#        [ 6.8728786,  9.826346 ],
#        [ 7.911105 ,  9.881013 ],
#        ...,
#        [ 6.1200323, 13.17525  ],
#        [ 9.047024 , 13.581496 ],
#        [ 7.7528   , 12.681393 ]], dtype=float32), 'adaptersfeature_standUMAP270.5cosine': array([[ 4.28584   ,  4.215642  ],
#        [ 7.2910004 ,  6.487056  ],
#        [ 9.416208  ,  3.4071143 ],
#        ...,
#        [ 8.640934  ,  0.84435296],
#        [10.111306  ,  2.1482234 ],
#        [ 9.9639015 ,  4.591223  ]], dtype=float32), 'adaptersfeature_standUMAP270.6euclidean': array([[-0.01560353,  6.460237  ],
#        [-2.479454  ,  5.6976805 ],
#        [-2.9833407 ,  6.3472476 ],
#        ...,
#        [-1.5368134 ,  8.828749  ],
#        [-4.5743175 , 10.026907  ],
#        [-3.693409  ,  8.8734665 ]], dtype=float32), 'adaptersfeature_standUMAP270.6manhattan': array([[ 7.062408, 12.151711],
#        [ 9.20677 , 11.414654],
#        [10.402362, 11.803439],
#        ...,
#        [ 9.144304, 15.140396],
#        [12.019268, 15.339047],
#        [10.750274, 14.841233]], dtype=float32), 'adaptersfeature_standUMAP270.6cosine': array([[3.2461693, 4.632617 ],
#        [4.9596434, 8.380949 ],
#        [8.538441 , 6.253942 ],
#        ...,
#        [9.744384 , 3.6435895],
#        [9.218889 , 6.000844 ],
#        [8.744505 , 8.4438505]], dtype=float32), 'adaptersfeature_standUMAP270.7euclidean': array([[ 3.308731 ,  2.8628185],
#        [ 1.1041589,  0.7487701],
#        [ 1.8880405,  0.6760715],
#        ...,
#        [ 4.5434475, -0.4704294],
#        [ 4.311795 , -3.1712232],
#        [ 3.5295064, -1.6025306]], dtype=float32), 'adaptersfeature_standUMAP270.7manhattan': array([[ 3.9223237,  6.1824865],
#        [ 6.5903473,  6.599375 ],
#        [ 6.9578404,  6.110055 ],
#        ...,
#        [ 5.749714 , 10.35332  ],
#        [ 8.495799 , 10.419742 ],
#        [ 7.425303 ,  9.184238 ]], dtype=float32), 'adaptersfeature_standUMAP270.7cosine': array([[ 2.1203923 ,  3.2941883 ],
#        [ 5.254602  ,  6.0755687 ],
#        [ 7.933811  ,  2.663781  ],
#        ...,
#        [ 8.260115  , -0.57649904],
#        [ 8.494677  ,  2.4786098 ],
#        [ 8.57967   ,  4.7894235 ]], dtype=float32), 'adaptersfeature_standUMAP270.8euclidean': array([[ 1.5359832,  3.5814629],
#        [ 3.4017377,  7.4672318],
#        [ 2.1859488,  7.039107 ],
#        ...,
#        [-1.6647699,  7.037673 ],
#        [-1.1771487,  9.315513 ],
#        [-0.5500166,  8.288932 ]], dtype=float32), 'adaptersfeature_standUMAP270.8manhattan': array([[ 5.19374  , -2.4067705],
#        [ 6.964268 , -2.04158  ],
#        [ 8.357773 , -2.439614 ],
#        ...,
#        [ 5.3499613, -5.5527296],
#        [ 8.30948  , -6.9450808],
#        [ 7.520188 , -5.8750772]], dtype=float32), 'adaptersfeature_standUMAP270.8cosine': array([[ 3.3331952,  2.884531 ],
#        [ 5.429124 ,  8.016403 ],
#        [ 9.870901 ,  5.4840198],
#        ...,
#        [11.1529665,  2.5617635],
#        [10.857372 ,  5.4169536],
#        [ 9.324103 ,  8.230283 ]], dtype=float32), 'adaptersfeature_standUMAP270.9euclidean': array([[ 2.8766236,  4.556405 ],
#        [ 0.8872105,  2.799687 ],
#        [ 1.0679537,  1.3454769],
#        ...,
#        [ 3.288659 ,  1.067704 ],
#        [ 3.0770848, -2.7889311],
#        [ 2.805748 , -0.8556018]], dtype=float32), 'adaptersfeature_standUMAP270.9manhattan': array([[ 4.879959 , -2.2164373],
#        [ 7.7033663, -2.5905256],
#        [ 8.916958 , -2.939164 ],
#        ...,
#        [ 6.3324747, -7.086658 ],
#        [10.18431  , -6.5266523],
#        [ 8.563107 , -5.440709 ]], dtype=float32), 'adaptersfeature_standUMAP270.9cosine': array([[ 2.7220616,  6.1612926],
#        [ 6.7923226, 10.108536 ],
#        [ 9.684013 ,  5.052831 ],
#        ...,
#        [10.420461 ,  1.7667469],
#        [10.878722 ,  5.1043415],
#        [11.093598 ,  8.441107 ]], dtype=float32), 'adaptersfeature_standUMAP280.1euclidean': array([[ 3.1530793 ,  7.850065  ],
#        [ 0.20758969,  6.9085503 ],
#        [ 0.7255144 ,  7.15628   ],
#        ...,
#        [ 1.084677  ,  9.39134   ],
#        [-0.7184482 ,  9.409822  ],
#        [ 0.18445644,  9.047715  ]], dtype=float32), 'adaptersfeature_standUMAP280.1manhattan': array([[ 5.369735 , 12.497647 ],
#        [ 6.884098 , 12.230084 ],
#        [ 7.3601484, 12.100659 ],
#        ...,
#        [ 6.4873896, 14.640206 ],
#        [ 8.544211 , 14.383528 ],
#        [ 7.5359063, 14.512667 ]], dtype=float32), 'adaptersfeature_standUMAP280.1cosine': array([[4.242028 , 4.3020806],
#        [5.6753583, 6.9255843],
#        [8.841963 , 5.776475 ],
#        ...,
#        [9.352548 , 2.8471422],
#        [9.306692 , 4.5853186],
#        [9.017609 , 6.266208 ]], dtype=float32), 'adaptersfeature_standUMAP280.2euclidean': array([[ 0.99527955,  6.4883313 ],
#        [-1.572959  ,  5.1992126 ],
#        [-1.02809   ,  5.443787  ],
#        ...,
#        [-1.2234484 ,  7.9030275 ],
#        [-3.3757763 ,  7.488576  ],
#        [-2.3739355 ,  6.98722   ]], dtype=float32), 'adaptersfeature_standUMAP280.2manhattan': array([[ 6.1359863, 11.565383 ],
#        [ 7.5280414, 11.556946 ],
#        [ 8.236292 , 11.923003 ],
#        ...,
#        [ 6.9329286, 14.117117 ],
#        [ 8.821979 , 14.440718 ],
#        [ 7.9315176, 14.334105 ]], dtype=float32), 'adaptersfeature_standUMAP280.2cosine': array([[ 4.9267716,  3.6142745],
#        [ 5.6866655,  6.9152465],
#        [ 9.216945 ,  5.8983316],
#        ...,
#        [10.447815 ,  3.389601 ],
#        [ 9.611337 ,  5.435511 ],
#        [ 9.050055 ,  6.9700947]], dtype=float32), 'adaptersfeature_standUMAP280.3euclidean': array([[ 2.052537  ,  5.7028356 ],
#        [ 1.4459885 ,  8.195253  ],
#        [ 1.5012852 ,  8.310248  ],
#        ...,
#        [-0.640502  ,  6.9116077 ],
#        [-1.5031654 ,  8.873673  ],
#        [-0.54547876,  8.285766  ]], dtype=float32), 'adaptersfeature_standUMAP280.3manhattan': array([[ 6.490829  ,  3.113891  ],
#        [ 8.24992   ,  2.5257447 ],
#        [ 8.700037  ,  2.5714362 ],
#        ...,
#        [ 7.050471  ,  0.49188903],
#        [ 9.227285  , -0.5447077 ],
#        [ 8.411146  , -0.17729735]], dtype=float32), 'adaptersfeature_standUMAP280.3cosine': array([[3.8579154, 4.0403113],
#        [5.3617597, 7.740316 ],
#        [8.860124 , 6.0451155],
#        ...,
#        [9.982168 , 4.166973 ],
#        [9.406654 , 5.8553414],
#        [8.611807 , 7.829844 ]], dtype=float32), 'adaptersfeature_standUMAP280.4euclidean': array([[ 2.4646497 ,  1.6895201 ],
#        [-0.9733271 ,  0.70973283],
#        [ 0.03822487,  0.3250766 ],
#        ...,
#        [ 1.7007263 , -1.7216957 ],
#        [-0.34067944, -2.545836  ],
#        [-0.11892023, -1.6748137 ]], dtype=float32), 'adaptersfeature_standUMAP280.4manhattan': array([[ 2.7215564,  5.9978905],
#        [ 4.2139254,  7.1956663],
#        [ 4.6465306,  7.5723953],
#        ...,
#        [ 1.74797  ,  8.984955 ],
#        [ 3.5902243, 10.589971 ],
#        [ 2.9854653, 10.128642 ]], dtype=float32), 'adaptersfeature_standUMAP280.4cosine': array([[3.6546407, 4.386691 ],
#        [6.0630746, 7.0602994],
#        [8.784891 , 4.6732955],
#        ...,
#        [8.296785 , 1.5411578],
#        [9.020373 , 3.4029338],
#        [9.571854 , 5.5370197]], dtype=float32), 'adaptersfeature_standUMAP280.5euclidean': array([[ 1.3750914,  6.223302 ],
#        [ 1.5445944,  9.166644 ],
#        [ 1.3389987,  9.074703 ],
#        ...,
#        [-1.327125 ,  7.852972 ],
#        [-1.8186972, 10.426843 ],
#        [-0.9929147,  9.920698 ]], dtype=float32), 'adaptersfeature_standUMAP280.5manhattan': array([[ 3.99482  , 10.341455 ],
#        [ 5.4590125, 10.881777 ],
#        [ 6.514225 , 11.272209 ],
#        ...,
#        [ 4.3084097, 13.828142 ],
#        [ 6.6776805, 14.698281 ],
#        [ 5.81851  , 14.16529  ]], dtype=float32), 'adaptersfeature_standUMAP280.5cosine': array([[2.7746835, 3.8736231],
#        [5.7510247, 6.2491584],
#        [8.72007  , 3.7817624],
#        ...,
#        [8.380554 , 0.4188305],
#        [8.845439 , 3.0126343],
#        [8.565438 , 5.0417147]], dtype=float32), 'adaptersfeature_standUMAP280.6euclidean': array([[ 4.718787  ,  1.6240202 ],
#        [ 1.7114906 , -0.23006965],
#        [ 2.067027  ,  0.12375618],
#        ...,
#        [ 5.1570725 , -1.2476351 ],
#        [ 3.7674794 , -3.7578115 ],
# ...
#        [ 0.4633039 ,  7.1963954 ,  5.105628  ],
#        [ 1.1460376 ,  7.273155  ,  4.5515084 ],
#        [ 0.64235336,  7.793769  ,  4.583674  ]], dtype=float32), 'adaptersnorm_vecsUMAP390.5euclidean': array([[10.182315 , -3.4101374,  7.5612183],
#        [ 6.147731 , -0.9667412, 13.431455 ],
#        [ 6.2701216, -0.7173229, 13.4341135],
#        ...,
#        [ 5.405486 ,  0.5530559, 14.589508 ],
#        [ 4.6440644,  0.3399941, 14.412582 ],
#        [ 4.867283 ,  0.8926305, 13.606392 ]], dtype=float32), 'adaptersnorm_vecsUMAP390.5manhattan': array([[-12.138635 ,  -7.1327043,  13.465093 ],
#        [  1.1626084,  19.925102 ,   9.734689 ],
#        [  2.1510751,  21.244364 ,   9.812253 ],
#        ...,
#        [  2.6094115,  22.111244 ,   9.690879 ],
#        [  2.8360443,  21.834229 ,   9.071813 ],
#        [  1.3469048,  22.339931 ,   8.9615755]], dtype=float32), 'adaptersnorm_vecsUMAP390.5cosine': array([[14.849313 ,  4.817377 ,  3.945677 ],
#        [-2.3625019,  6.7216353,  7.077099 ],
#        [-2.7787967,  5.6852922,  7.673846 ],
#        ...,
#        [-2.0934513,  5.9097486,  6.588657 ],
#        [-1.9111859,  5.607791 ,  6.430812 ],
#        [-2.1694517,  6.1706614,  7.818855 ]], dtype=float32), 'adaptersnorm_vecsUMAP390.6euclidean': array([[11.6841755 , -7.7597246 ,  9.843084  ],
#        [10.494344  , -1.8093153 , 19.796343  ],
#        [10.812889  , -1.2399793 , 19.873272  ],
#        ...,
#        [ 9.672524  , -0.9399522 , 21.643461  ],
#        [10.1722555 , -0.75113624, 22.396116  ],
#        [10.940289  , -1.836667  , 22.175974  ]], dtype=float32), 'adaptersnorm_vecsUMAP390.6manhattan': array([[  0.85157627, -21.098017  ,  21.378468  ],
#        [ 19.691435  , -14.688925  ,  20.019556  ],
#        [ 18.142149  , -15.827944  ,  21.228714  ],
#        ...,
#        [ 18.597898  , -15.943127  ,  22.463333  ],
#        [ 18.993464  , -16.349539  ,  22.45085   ],
#        [ 18.85295   , -17.403175  ,  20.930426  ]], dtype=float32), 'adaptersnorm_vecsUMAP390.6cosine': array([[12.184427 ,  1.5308607,  4.6589785],
#        [-1.8567339,  6.309871 ,  2.4622421],
#        [-2.5746179,  7.790629 ,  3.410819 ],
#        ...,
#        [-2.1417553,  6.18128  ,  3.4983833],
#        [-1.7135737,  6.2653837,  4.14531  ],
#        [-1.2701353,  7.287364 ,  2.4425523]], dtype=float32), 'adaptersnorm_vecsUMAP390.7euclidean': array([[16.915998 , -1.5408381, 12.041297 ],
#        [10.759956 , -4.200235 , 10.232283 ],
#        [10.380566 , -4.329352 , 11.306004 ],
#        ...,
#        [ 8.964893 , -5.4799643, 10.041546 ],
#        [ 9.712755 , -5.805977 ,  9.933913 ],
#        [ 9.81339  , -6.2223434,  9.595902 ]], dtype=float32), 'adaptersnorm_vecsUMAP390.7manhattan': array([[  1.308462  ,   0.80747724,  25.900818  ],
#        [  7.4460464 , -19.575602  ,  28.247948  ],
#        [  5.162143  , -20.891619  ,  27.707275  ],
#        ...,
#        [  4.8010197 , -21.605894  ,  27.623665  ],
#        [  5.2709846 , -21.658432  ,  27.15965   ],
#        [  6.5895934 , -22.626488  ,  27.916374  ]], dtype=float32), 'adaptersnorm_vecsUMAP390.7cosine': array([[14.147351 ,  4.0875363,  4.846531 ],
#        [-3.5749319,  5.219165 ,  4.0161843],
#        [-5.239626 ,  6.0333476,  5.23861  ],
#        ...,
#        [-3.4540203,  6.254676 ,  5.018209 ],
#        [-2.8944352,  6.061802 ,  5.4471874],
#        [-4.132417 ,  4.7083435,  4.5831046]], dtype=float32), 'adaptersnorm_vecsUMAP390.8euclidean': array([[17.040718 , 10.433061 ,  8.709997 ],
#        [20.136007 ,  7.3916993,  9.449195 ],
#        [19.53442  ,  7.2153444,  8.803246 ],
#        ...,
#        [21.087103 ,  5.522931 , 10.144233 ],
#        [21.496134 ,  5.8299065, 10.770534 ],
#        [20.787312 ,  6.0968647, 11.689794 ]], dtype=float32), 'adaptersnorm_vecsUMAP390.8manhattan': array([[ 3.1892046e-01, -3.0381372e+01,  1.7264265e+01],
#        [ 1.5618519e+00, -2.4199087e+01,  2.1146433e+01],
#        [ 2.7542017e-02, -2.6024904e+01,  2.1417091e+01],
#        ...,
#        [ 1.7844026e+00, -2.5616282e+01,  2.3677498e+01],
#        [ 8.4687829e-01, -2.6645855e+01,  2.3386045e+01],
#        [ 4.9783236e-01, -2.6696232e+01,  2.2736420e+01]], dtype=float32), 'adaptersnorm_vecsUMAP390.8cosine': array([[11.378782  ,  9.524256  ,  6.2015805 ],
#        [-2.6527169 ,  6.7744823 ,  0.9555337 ],
#        [-0.69385165,  7.245861  ,  0.058679  ],
#        ...,
#        [-1.4952824 ,  6.969501  ,  2.272253  ],
#        [-1.4717379 ,  6.2104063 ,  2.759519  ],
#        [-1.6087873 ,  6.212615  , -0.05302377]], dtype=float32), 'adaptersnorm_vecsUMAP390.9euclidean': array([[10.493791 ,  9.175957 ,  1.8693392],
#        [ 9.4715185, 12.184895 ,  4.051706 ],
#        [ 9.26229  , 12.794574 ,  4.820505 ],
#        ...,
#        [ 8.223686 , 13.946651 ,  4.9230165],
#        [ 7.3427916, 13.770642 ,  4.6962614],
#        [ 7.355507 , 13.295668 ,  3.1227648]], dtype=float32), 'adaptersnorm_vecsUMAP390.9manhattan': array([[ 28.676783  , -16.875757  ,  -0.60024416],
#        [ 24.052452  ,  -9.092072  ,  -4.459921  ],
#        [ 22.030617  ,  -9.654386  ,  -6.183292  ],
#        ...,
#        [ 21.7871    ,  -8.941989  ,  -7.5329003 ],
#        [ 21.918478  ,  -9.043441  ,  -7.3430715 ],
#        [ 23.33272   ,  -9.592073  ,  -8.059839  ]], dtype=float32), 'adaptersnorm_vecsUMAP390.9cosine': array([[ 9.984552  ,  5.981168  ,  3.9850175 ],
#        [-0.2338173 ,  4.543261  ,  8.605372  ],
#        [-0.44403008,  2.7579985 ,  9.274388  ],
#        ...,
#        [-0.6724655 ,  4.0830817 ,  7.5754294 ],
#        [-1.9192892 ,  3.768812  ,  7.741161  ],
#        [-0.3826071 ,  3.9544456 ,  9.822093  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.1euclidean': array([[10.945123 , 13.406437 ,  1.3549515],
#        [12.3389225,  9.094325 ,  3.2345896],
#        [11.565896 ,  8.50998  ,  3.0412831],
#        ...,
#        [13.167947 ,  8.829856 ,  1.9493372],
#        [12.699444 ,  8.960512 ,  1.7003949],
#        [12.386596 ,  9.145055 ,  1.8066185]], dtype=float32), 'adaptersnorm_vecsUMAP3100.1manhattan': array([[21.199745 , 17.40968  , 10.810129 ],
#        [24.550585 ,  7.8245225,  1.836278 ],
#        [24.114382 ,  9.113693 ,  2.9253187],
#        ...,
#        [24.223528 ,  9.512739 ,  2.5174327],
#        [24.360008 ,  9.472612 ,  2.9717207],
#        [24.963024 ,  9.097177 ,  2.9787078]], dtype=float32), 'adaptersnorm_vecsUMAP3100.1cosine': array([[10.969915 ,  1.9142852,  6.9679704],
#        [-2.770559 ,  5.985048 ,  5.9271793],
#        [-2.8286822,  7.0280814,  6.4436727],
#        ...,
#        [-2.9003296,  5.858087 ,  6.017424 ],
#        [-3.16398  ,  5.7683425,  5.7963896],
#        [-2.6824358,  6.420332 ,  5.618484 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.2euclidean': array([[ 3.311909 ,  6.157418 , 10.462806 ],
#        [ 6.1217084,  4.686811 , 15.065527 ],
#        [ 6.786612 ,  4.219748 , 15.092385 ],
#        ...,
#        [ 5.6525073,  4.690512 , 15.856801 ],
#        [ 5.592892 ,  4.307564 , 16.434664 ],
#        [ 5.5702333,  3.7964675, 15.822986 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.2manhattan': array([[ 1.4691023, 14.738907 , 10.911051 ],
#        [ 2.8560438, 15.213405 , 22.567932 ],
#        [ 3.574874 , 17.102297 , 23.31741  ],
#        ...,
#        [ 4.318477 , 17.192043 , 23.289595 ],
#        [ 4.281901 , 17.555021 , 22.880611 ],
#        [ 3.5005593, 17.453398 , 23.183222 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.2cosine': array([[13.731319 ,  5.0519853,  3.4103265],
#        [-2.9222045,  3.200532 ,  6.2024403],
#        [-2.7963917,  1.7529444,  6.134096 ],
#        ...,
#        [-3.6587422,  2.75293  ,  6.1679688],
#        [-3.30999  ,  3.0240734,  5.5323415],
#        [-3.618478 ,  2.4220133,  5.798851 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.3euclidean': array([[ 6.034174 , 10.359598 ,  8.380047 ],
#        [ 5.5546694,  8.007948 , 13.602022 ],
#        [ 6.30162  ,  7.9160066, 14.021978 ],
#        ...,
#        [ 5.4859524,  7.674271 , 14.596766 ],
#        [ 5.4751973,  7.7624083, 15.252458 ],
#        [ 5.0922856,  7.021999 , 15.16746  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.3manhattan': array([[ 5.4352107, -7.1356797, -1.7988887],
#        [28.650528 ,  4.632282 ,  5.721189 ],
#        [27.76447  ,  3.8115761,  7.5112176],
#        ...,
#        [27.683855 ,  3.0867546,  7.639907 ],
#        [28.151958 ,  2.22655  ,  7.599199 ],
#        [28.815876 ,  2.8568382,  7.5306935]], dtype=float32), 'adaptersnorm_vecsUMAP3100.3cosine': array([[13.316553  ,  2.9094036 ,  1.0433074 ],
#        [-0.47089955,  3.2210526 ,  6.72606   ],
#        [-0.5246638 ,  2.0234656 ,  6.6473026 ],
#        ...,
#        [-0.38172072,  3.0303776 ,  6.71931   ],
#        [-0.4293905 ,  3.252248  ,  6.0286684 ],
#        [-1.0841554 ,  2.8701339 ,  7.043242  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.4euclidean': array([[14.518559  , -0.2235753 , -0.13089761],
#        [11.443891  , -4.4074316 ,  3.0295498 ],
#        [11.6322365 , -5.0360847 ,  3.0377188 ],
#        ...,
#        [10.58898   , -4.1324067 ,  2.0708394 ],
#        [10.429689  , -5.302849  ,  2.4380848 ],
#        [10.286378  , -5.2617364 ,  1.5893658 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.4manhattan': array([[28.812548, 18.205185, 21.457355],
#        [26.069624, 13.265608, 13.797317],
#        [25.845364, 12.725634, 15.071633],
#        ...,
#        [26.338793, 11.539544, 15.394488],
#        [26.796818, 11.591413, 15.854363],
#        [27.898384, 12.254113, 15.497365]], dtype=float32), 'adaptersnorm_vecsUMAP3100.4cosine': array([[ 9.802091  ,  4.131141  ,  7.2265935 ],
#        [-0.05907976,  7.2429953 ,  7.726271  ],
#        [ 1.0536492 ,  5.6620536 ,  8.167282  ],
#        ...,
#        [-0.34845534,  6.2208743 ,  7.659117  ],
#        [-0.53025895,  6.512506  ,  7.9196377 ],
#        [ 0.5126809 ,  6.9416933 ,  8.180109  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.5euclidean': array([[17.311909  ,  7.816027  , 11.56187   ],
#        [15.922365  ,  0.36212775, 11.436163  ],
#        [16.072815  , -0.15035237, 10.048627  ],
#        ...,
#        [16.671366  , -0.6161002 , 10.743028  ],
#        [16.482244  , -1.1874195 , 11.304208  ],
#        [16.071941  , -2.109761  , 11.793069  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.5manhattan': array([[ -6.5755744 ,   8.864903  , -17.75553   ],
#        [  0.27675262,  10.914537  ,  -9.644559  ],
#        [ -0.53513026,   9.854297  , -10.547554  ],
#        ...,
#        [ -0.5490168 ,   9.790246  , -11.9899    ],
#        [ -0.8978133 ,  11.438323  , -12.022372  ],
#        [ -1.3725804 ,  11.264472  , -11.620264  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.5cosine': array([[16.904814  ,  4.451155  ,  2.9378738 ],
#        [ 0.4202808 ,  4.8392954 ,  7.577675  ],
#        [ 0.4710447 ,  3.417521  ,  7.54739   ],
#        ...,
#        [-0.35408744,  4.75846   ,  7.0827165 ],
#        [-0.39320934,  4.713869  ,  6.660432  ],
#        [ 1.2504413 ,  4.0629835 ,  7.2315474 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.6euclidean': array([[ 7.8204055,  5.538254 , 17.114418 ],
#        [ 5.188277 ,  6.9904695, 13.788322 ],
#        [ 3.817003 ,  6.7129087, 12.980249 ],
#        ...,
#        [ 4.0413284,  7.281374 , 12.395593 ],
#        [ 3.7252398,  8.331014 , 13.194974 ],
#        [ 4.5453324,  8.877649 , 12.387463 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.6manhattan': array([[ 2.035425 , -6.1326427, 31.522963 ],
#        [-3.878328 ,  9.765443 , 18.921728 ],
#        [-4.908482 , 11.320844 , 19.008127 ],
#        ...,
#        [-5.056338 , 11.918235 , 19.818335 ],
#        [-5.065501 , 12.6334915, 20.042416 ],
#        [-5.057803 , 11.589881 , 20.466068 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.6cosine': array([[11.671102  ,  7.07584   ,  6.022313  ],
#        [-0.17211899,  2.043461  ,  9.474801  ],
#        [-1.870021  ,  2.0265257 ,  8.930911  ],
#        ...,
#        [-0.42771158,  2.7245147 ,  8.510645  ],
#        [-0.16475233,  3.4753554 ,  8.189687  ],
#        [-1.428273  ,  2.7546055 ,  9.95395   ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.7euclidean': array([[10.737951 ,  1.4191009,  3.7817478],
#        [10.403058 ,  8.705389 ,  5.000498 ],
#        [10.396769 ,  9.098493 ,  6.1174407],
#        ...,
#        [ 8.922528 ,  8.751617 ,  4.8240867],
#        [ 8.15341  , 10.043329 ,  5.009892 ],
#        [ 8.514209 , 10.978892 ,  5.2802887]], dtype=float32), 'adaptersnorm_vecsUMAP3100.7manhattan': array([[ 3.6634557 , -4.884279  , -9.275255  ],
#        [-3.3993366 ,  1.277704  , -8.017024  ],
#        [-4.5431447 ,  1.0254856 , -6.0265555 ],
#        ...,
#        [-5.2867107 ,  1.1832899 , -5.46951   ],
#        [-5.9275203 ,  1.5193979 , -6.013797  ],
#        [-5.944739  ,  0.86326575, -7.467252  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.7cosine': array([[ 6.8925366,  1.5182334,  4.7176957],
#        [-2.700326 ,  4.610365 ,  8.541894 ],
#        [-3.5069864,  5.9849486,  8.058985 ],
#        ...,
#        [-1.9263914,  4.7420335,  8.789963 ],
#        [-1.6062784,  5.4855123,  7.9836564],
#        [-2.0392091,  5.4761634,  9.366077 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.8euclidean': array([[11.244478 ,  7.6107917, 13.795177 ],
#        [ 7.219528 ,  1.163706 ,  9.380965 ],
#        [ 7.456441 ,  0.7281847, 10.639702 ],
#        ...,
#        [ 6.165408 ,  1.5071676, 10.91869  ],
#        [ 5.2418156,  2.035983 , 10.711401 ],
#        [ 4.8131785,  1.4924995, 10.347821 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.8manhattan': array([[17.07925  , -9.802828 , 27.937304 ],
#        [ 7.858169 ,  2.6106825, 24.93921  ],
#        [ 6.526399 ,  1.8711629, 24.886631 ],
#        ...,
#        [ 5.880218 ,  2.1146812, 23.148136 ],
#        [ 5.159383 ,  2.6353269, 23.383156 ],
#        [ 5.192856 ,  1.7503855, 24.843588 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.8cosine': array([[ 8.299803 ,  2.9752326,  7.329829 ],
#        [-1.5947963,  5.2067614,  4.8513384],
#        [-1.8847587,  3.4527965,  3.9050987],
#        ...,
#        [-2.5614269,  5.015401 ,  6.1703987],
#        [-1.331277 ,  4.920559 ,  5.609671 ],
#        [-2.1210735,  4.45021  ,  6.2420015]], dtype=float32), 'adaptersnorm_vecsUMAP3100.9euclidean': array([[10.513683 ,  5.0354733, 20.950506 ],
#        [ 9.546648 ,  8.436918 , 15.883855 ],
#        [ 9.988559 ,  9.299685 , 15.935824 ],
#        ...,
#        [10.820285 ,  9.266521 , 17.52707  ],
#        [10.688078 ,  9.417751 , 17.953417 ],
#        [ 9.1943865,  9.168043 , 18.905684 ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.9manhattan': array([[-7.3323703, 13.633996 , 13.072273 ],
#        [-3.8030543, -3.010582 , 33.139523 ],
#        [-2.4113514, -4.7009907, 35.056774 ],
#        ...,
#        [-2.7242928, -6.295068 , 33.90479  ],
#        [-2.7035856, -6.218944 , 34.493385 ],
#        [-3.4981723, -5.598806 , 35.18433  ]], dtype=float32), 'adaptersnorm_vecsUMAP3100.9cosine': array([[10.085285  , -0.793884  ,  7.69825   ],
#        [ 1.6993651 ,  1.8150187 ,  2.8603735 ],
#        [ 1.4893403 ,  0.71180415,  3.5555258 ],
#        ...,
#        [ 0.92081445,  2.210573  ,  2.8122082 ],
#        [ 0.05575167,  2.1409156 ,  2.8924487 ],
#        [ 1.563362  ,  0.9900849 ,  2.2896428 ]], dtype=float32), 'adaptersnorm_vecsPCA2nanana': array([[-0.7611744 , -0.22712111],
#        [-0.56790876, -0.41526374],
#        [-0.6327521 , -0.31843397],
#        ...,
#        [-0.52242064, -0.37812918],
#        [-0.64165807, -0.30483922],
#        [-0.63251954, -0.30371636]], dtype=float32), 'adaptersnorm_vecsPCA3nanana': array([[-0.76125103, -0.22732155, -0.3210576 ],
#        [-0.5679084 , -0.41531557, -0.19824573],
#        [-0.632752  , -0.31843352, -0.19714485],
#        ...,
#        [-0.5224202 , -0.37812898, -0.16646677],
#        [-0.6416578 , -0.30483904, -0.18773918],
#        [-0.6325193 , -0.30371618, -0.2058246 ]], dtype=float32), 'adaptersfeature_standPCA2nanana': array([[14.319414  , -0.40888062],
#        [ 3.7643025 , -9.870563  ],
#        [-1.9466541 , -5.3885117 ],
#        ...,
#        [-4.7041745 ,  3.7575939 ],
#        [-9.311814  , -0.5849821 ],
#        [-3.2427604 , -4.6475043 ]], dtype=float32), 'adaptersfeature_standPCA3nanana': array([[14.319401  , -0.40888205,  1.2155566 ],
#        [ 3.7642987 , -9.870582  ,  2.9499607 ],
#        [-1.9466571 , -5.3885098 ,  1.3514084 ],
#        ...,
#        [-4.704173  ,  3.757602  ,  2.410176  ],
#        [-9.311815  , -0.5849796 ,  3.421627  ],
#        [-3.2427604 , -4.6475105 ,  1.4884166 ]], dtype=float32)}

# %%
#selecting best values from previous dimensionality reduction and placing them in iterable array
data_gen_array = np.full((34,), 'adapters')

pre_proc_array_1 = np.full((21,), 'feature_stand')
pre_proc_array_2 = np.full((13,), 'norm_vecs')
pre_proc_array = np.concatenate((pre_proc_array_1, pre_proc_array_2))

dim_red_array = np.full((34,),'UMAP')

n_dims_array_1 = np.full((10,),'2')
n_dims_array_2 = np.full((11,), '3')
n_dims_array_3 = np.full((7,),'2')
n_dims_array_4 = np.full((6,), '3')
n_dims_array = np.concatenate((n_dims_array_1, n_dims_array_2, n_dims_array_3, n_dims_array_4))

neighbors_array = np.full((34,), '2')

dist_array = ['0.4', '0.3', '0.6', '0.3', '0.7', '0.9', '0.3', '0.7', '0.5', '0.4', '0.4', '0.3', '0.6', '0.5', '0.6', '0.5', '0.6', '0.7','0.7','0.8','0.5','0.4','0.4','0.6','0.8','0.9','0.5','0.7','0.1', '0.2', '0.5', '0.6', '0.4','0.3']

metric_array = ['cosine','cosine','cosine','euclidean','euclidean','euclidean','euclidean','manhattan','euclidean','euclidean','cosine','cosine','cosine','cosine','euclidean','manhattan','manhattan','euclidean','manhattan','euclidean','euclidean','euclidean','manhattan','euclidean','euclidean','euclidean','manhattan','euclidean','euclidean','manhattan','manhattan','manhattan','manhattan','euclidean']

#iter_array = zip(data_gen_array, pre_proc_array, dim_red_array, n_dims_array, neighbors_array, dist_array, metric_array)
iter_array = np.column_stack((data_gen_array, pre_proc_array, dim_red_array, n_dims_array, neighbors_array, dist_array, metric_array))

# %% [markdown]
# # 6. Clustering
# Finally, we will have to cluster the reduced dimensionality embeddings.
#
# In this section, we will try out different clustering algorithms with different hyperparameters each. We will furthermore use the xxx metric to support qualitative assesments of the clustering, enabling us to choose our final set of hyperparameters.
#
# Please note that this metric calculates the quality score of the clustering based on distance, i.e. factors such as cluster diameter, average distance between cluster points, distance between separate clusters etc..
# Yet, as UMAP focuses on preserving the local structure of the data, the distances between clusters as well as the size of the clusters themselves are not interpretable. Moreover, some of the used clustering algorithms do not cluster according to distance but according to density, distribution, or graph structures. Therefore, the used metric does not perfectly evaluate the quality of the clustering and merely serves as an approximative assistance for the evalutation.

# %% [markdown]
# ## 6.1 K-Means

# %%
#performing k-means clustering by iterating over plausible hyperparameter values

#creating dict to track ch scores
ch_tracker = {}
print(iter_array)
#iterating over the different hyperparameter values and reduced dimensionality embeddings
for data_generation, pre_processing, dim_reduction, n_dims, n_neighbors, min_dist, measure in iter_array: #iteration over different reduced dim embeddings
  reduced_data = embeddings[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure]
  print(reduced_data)
  for n_clusters in np.concatenate((range(2,10,1),range(10,101,5))): #iterating over number of clusters

    kmeans = KMeans(init="random", n_clusters=n_clusters, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(reduced_data)
    labels = kmeans.labels_ #extracting labels of each sample
    ch_score = metrics.calinski_harabasz_score(reduced_data, labels)
    ch_tracker[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure + str(n_clusters)] = ch_score

    if n_dims == '2':
      #configuring plot settings, one color for each created label
      plt.figure()
      plt.scatter(reduced_data[:,0], reduced_data[:,1], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score) + '    nr clusters:' + str(n_clusters) + '\n Kmeans', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'k_means'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)


    else:
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score)+ '    nr clusters:' + str(n_clusters) + '\n Kmeans', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'k_means'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)
# Out:
# [['adapters' 'feature_stand' 'UMAP' '2' '2' '0.4' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.3' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.6' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.3' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.7' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.9' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.3' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.7' 'manhattan']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.5' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '2' '2' '0.4' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.4' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.3' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.6' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.5' 'cosine']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.6' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.5' 'manhattan']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.6' 'manhattan']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.7' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.7' 'manhattan']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.8' 'euclidean']
#  ['adapters' 'feature_stand' 'UMAP' '3' '2' '0.5' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.4' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.4' 'manhattan']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.6' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.8' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.9' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.5' 'manhattan']
#  ['adapters' 'norm_vecs' 'UMAP' '2' '2' '0.7' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '3' '2' '0.1' 'euclidean']
#  ['adapters' 'norm_vecs' 'UMAP' '3' '2' '0.2' 'manhattan']
#  ['adapters' 'norm_vecs' 'UMAP' '3' '2' '0.5' 'manhattan']
#  ['adapters' 'norm_vecs' 'UMAP' '3' '2' '0.6' 'manhattan']
#  ['adapters' 'norm_vecs' 'UMAP' '3' '2' '0.4' 'manhattan']
#  ['adapters' 'norm_vecs' 'UMAP' '3' '2' '0.3' 'euclidean']]
# [[ 3.378288  -1.6519204]
#  [-1.3375239 17.066078 ]
#  [ 8.173094  16.256348 ]
#  ...
#  [15.8140135 -1.2894058]
#  [16.07733    9.048892 ]
#  [ 7.2523127 15.406978 ]]
# <ipython-input-32-c49c81eb4d5a>:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# [[-1.4098315 -1.2458988]
#  [-0.19835   15.155466 ]
#  [ 5.0484977 15.255997 ]
#  ...
#  [17.869959   1.8534476]
#  [16.638546  10.022413 ]
#  [ 5.547081  14.886041 ]]
# [[-1.9019655 -1.3828804]
#  [ 0.7018281 13.06356  ]
#  [ 4.6110716 16.978762 ]
#  ...
#  [15.668492  -2.1295192]
#  [16.923805   9.526438 ]
#  [ 5.3650784 16.781603 ]]
# [[ 5.214946    0.12763412]
#  [22.352123    6.529311  ]
#  [19.70649     5.9890723 ]
#  ...
#  [ 6.7625623   1.7476624 ]
#  [-1.931388   13.321524  ]
#  [ 3.0041745  13.011845  ]]
# [[ 9.590451    0.4823868 ]
#  [16.041098   10.058055  ]
#  [18.187893    8.43209   ]
#  ...
#  [ 8.312008    0.6020971 ]
#  [-0.23025209 15.540795  ]
#  [ 2.9037366  12.9291725 ]]
# [[10.035096    0.6314846 ]
#  [17.263569   12.44225   ]
#  [16.062506   11.140568  ]
#  ...
#  [ 8.945465   -0.33891827]
#  [ 0.51793516 15.834822  ]
#  [ 3.3785067  17.647436  ]]
# [[ 5.214946    0.12763412]
#  [22.352123    6.529311  ]
#  [19.70649     5.9890723 ]
#  ...
#  [ 6.7625623   1.7476624 ]
#  [-1.931388   13.321524  ]
#  [ 3.0041745  13.011845  ]]
# [[ 1.9714965 10.871984 ]
#  [ 6.218172   2.109453 ]
#  [-8.533468  -2.4101446]
#  ...
#  [ 2.9432032 10.303691 ]
#  [13.724179  -3.5490363]
#  [-6.268562  -0.5372991]]
# [[ 9.600774   5.5791345]
#  [21.47772    2.8897264]
#  [18.237797   4.523575 ]
#  ...
#  [ 9.93182    4.086981 ]
#  [ 0.5093076 11.334043 ]
#  [ 2.5185466 14.410665 ]]
# [[5.6444387e+00 5.7873625e-01]
#  [1.8724371e+01 5.6788435e+00]
#  [1.5861171e+01 4.5542035e+00]
#  ...
#  [5.8588686e+00 1.1747843e+00]
#  [3.4128940e-03 1.5143249e+01]
#  [3.5938938e+00 1.5963261e+01]]
# [[ 1.5319161  -1.2435741  11.521343  ]
#  [-0.6435377  11.252324    0.06131751]
#  [ 4.6132402  15.104361    5.905542  ]
#  ...
#  [13.091432    1.4407935   5.445667  ]
#  [13.738676    7.91418     7.70201   ]
#  [ 5.5111475  14.817496    5.2960987 ]]
# [[ 2.610085  -2.135482  14.562825 ]
#  [-1.051719  13.205453  -1.126486 ]
#  [ 4.4293847 13.190393   4.0186625]
#  ...
#  [13.749505   1.1408285  8.438605 ]
#  [15.287158   8.239742   6.57097  ]
#  [ 5.2753854 12.593426   3.856156 ]]
# [[-0.41996306  2.2518764   6.65242   ]
#  [ 0.23665272 14.313826   -3.2241874 ]
#  [ 4.893522   12.018318    4.5585785 ]
#  ...
#  [14.104957   -1.0580169   7.183682  ]
#  [13.876215    7.4979143   8.177044  ]
#  [ 5.001149   13.037808    5.4951224 ]]
# [[-2.7216487 -1.287108   9.928141 ]
#  [ 2.268335  15.443138   1.2731147]
#  [ 5.757635  12.378276   4.4516068]
#  ...
#  [14.476949  -1.2501091  5.9195037]
#  [13.89857    7.3499846  5.675912 ]
#  [ 5.8616576 13.079015   3.8822744]]
# [[11.201573   4.1410604  3.5930614]
#  [ 3.761448   2.081644  -1.3001806]
#  [ 5.0455036  1.3140633  0.5739406]
#  ...
#  [12.313381   3.424521   4.450391 ]
#  [ 0.7060701 12.480388   5.4526362]
#  [ 4.624893  12.165537   5.924695 ]]
# [[12.083579   7.0512366  3.400494 ]
#  [ 7.966644  12.9788475  6.6550255]
#  [ 0.5738803 12.980108   3.0243459]
#  ...
#  [11.85524    6.3790145  3.4405787]
#  [ 4.231246  -3.409822   4.2226214]
#  [ 3.4886866 12.051982   3.6836536]]
# [[11.186675   5.259546   5.860833 ]
#  [ 8.351415   8.613872   6.439145 ]
#  [ 1.3586605 10.821148   0.8896059]
#  ...
#  [12.907467   5.193657   5.4536314]
#  [ 2.8386915 -1.9841604  6.3530526]
#  [ 3.3710072 12.102853   2.6372054]]
# [[ 9.940888    3.5779762   7.3981295 ]
#  [ 1.7798047   2.8968284   0.33891186]
#  [ 3.2763307   3.5324492   2.6074038 ]
#  ...
#  [10.0838785   4.0966873   6.2894607 ]
#  [ 1.6426805  11.360019    4.963182  ]
#  [ 3.4973536  13.829397    6.3800693 ]]
# [[11.516554   4.435197   6.07126  ]
#  [10.881143  -2.7137952  7.89258  ]
#  [ 1.022451  16.296503   4.5799437]
#  ...
#  [12.077216   4.8009057  5.257458 ]
#  [ 5.4293723 -1.6563407  4.765834 ]
#  [ 0.9791383 13.446228   4.8412814]]
# [[12.593359   3.230019   6.3626695]
#  [ 3.480679   3.962434  -0.9634296]
#  [ 3.9873397  1.1293269  0.6529676]
#  ...
#  [11.824949   3.6467643  6.474092 ]
#  [ 3.058251  12.1453     1.5027864]
#  [ 5.0182896 12.204166   3.6761072]]
# [[10.495527   3.9149585  4.7140093]
#  [ 2.5215962  3.3327749  1.3719699]
#  [ 2.122927   4.414495   3.0915744]
#  ...
#  [11.723338   3.774848   4.673926 ]
#  [ 3.0403829 12.240608   5.1289167]
#  [ 4.909783  11.259955   5.8965282]]
# [[ 9.049004    6.696226  ]
#  [-3.7298338   9.438916  ]
#  [-0.91984797 -2.8448792 ]
#  ...
#  [ 0.2660024  13.34925   ]
#  [ 4.459212   14.026895  ]
#  [ 0.5957551  -2.3028097 ]]
# [[-1.797315   6.999494 ]
#  [14.302881   7.327966 ]
#  [ 9.261686  -3.316127 ]
#  ...
#  [12.636196   6.759401 ]
#  [ 5.5865235 12.083021 ]
#  [ 9.229552  -3.0054522]]
# [[10.658868   8.651392 ]
#  [-2.6393995  5.329211 ]
#  [ 2.4371445 -1.1995167]
#  ...
#  [-4.8431516  4.5368505]
#  [-4.515111  15.5804825]
#  [ 2.4539886 -2.5999131]]
# [[10.740983    6.9103723 ]
#  [-0.1460893  10.752868  ]
#  [ 0.12905452 -1.2898391 ]
#  ...
#  [-8.03317     8.756297  ]
#  [ 2.573965    6.244577  ]
#  [-0.32648262 -3.410438  ]]
# [[11.276515    8.216902  ]
#  [-2.5507698   7.797714  ]
#  [-0.13711046 -3.1213799 ]
#  ...
#  [-0.7801755  13.457864  ]
#  [-2.5003698  19.048332  ]
#  [ 0.08369543 -1.0605403 ]]
# [[-2.133615    7.2204003 ]
#  [15.897543   11.639612  ]
#  [10.596522   -1.6331398 ]
#  ...
#  [13.938391    9.121321  ]
#  [14.120966   16.410635  ]
#  [10.85679    -0.95494354]]
# [[10.502443    6.503981  ]
#  [-0.4765477  10.055218  ]
#  [ 2.0012157   0.40303588]
#  ...
#  [-5.128575    4.962189  ]
#  [ 3.7107778  12.995455  ]
#  [ 1.2624254  -0.57416326]]
# [[ 9.746924    7.235219    8.089556  ]
#  [-0.42555544  9.418589    7.8215857 ]
#  [ 1.2280782  -0.79599214  8.094874  ]
#  ...
#  [-2.949458   11.717818    8.325697  ]
#  [ 6.513157   14.886655   14.577647  ]
#  [ 1.0036223  -1.9274433   7.8554673 ]]
# [[ 0.04466799  6.528707    7.253101  ]
#  [ 9.449514   11.968399    4.304738  ]
#  [ 8.400243    0.36328086  8.407286  ]
#  ...
#  [ 9.182055    8.814225    6.0710106 ]
#  [ 6.1706524  12.510759    8.992026  ]
#  [ 7.6975217   0.3138968   8.253422  ]]
# [[ 0.10792694  6.684       5.4068217 ]
#  [10.875266   11.84872     6.679228  ]
#  [ 8.09438    -0.68266124  5.868593  ]
#  ...
#  [ 9.119224    9.24156     7.148498  ]
#  [ 9.598932   11.895095    9.709298  ]
#  [ 7.8512464   0.02110372  5.700891  ]]
# [[-0.78900665  7.098184    6.167233  ]
#  [13.639279    7.551558    5.3952336 ]
#  [ 6.662644    0.8897664   5.55011   ]
#  ...
#  [10.261376   11.018151    5.955415  ]
#  [ 6.552043   11.135255    0.3930403 ]
#  [ 6.662765    0.4486616   5.038697  ]]
# [[ 0.5555643  7.0605435  4.0083036]
#  [11.854787   6.3599324  7.8849673]
#  [ 7.778596  -1.052167   7.417421 ]
#  ...
#  [10.649823   8.353419   7.9005713]
#  [13.057314   8.714005   3.643057 ]
#  [ 7.77766   -0.6159859  7.4822726]]
# [[10.378744    8.074292    7.833686  ]
#  [-0.9981989   5.976625    8.424854  ]
#  [ 3.132286   -0.50412637  6.183713  ]
#  ...
#  [-1.108087    6.2692285  10.77806   ]
#  [ 3.6303914   7.964031   17.068157  ]
#  [ 2.1693807  -0.3194137   6.03419   ]]

# %%
#Determining the best clusters according to ch score and printing them in table
largest_keys = sorted(ch_tracker, key=ch_tracker.get, reverse=True)[:5]
largest_vals = [ch_tracker[x] for x in largest_keys]
length = len(largest_vals)
heading = np.empty(length, dtype = str)
heading[:] = 'value'
pd.DataFrame(largest_vals, index = largest_keys, columns=["values"])
# Out:
# Empty DataFrame
# Columns: [values]
# Index: []

# %% [markdown]
# ## 6.2 Agglomerative Clustering

# %%
#performing Agglomerative clustering by iterating over plausible hyperparameter values

#creating dict to track ch scores
ch_tracker = {}

#iterating over the different hyperparameter values and reduced dimensionality embeddings
for data_generation, pre_processing, dim_reduction, n_dims, n_neighbors, min_dist, measure in iter_array: #iteration over different reduced dim embeddings
  reduced_data = embeddings[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure]
  for n_clusters in np.concatenate((range(2,10,1),range(10,101,5))): #iterating over number of clusters
    agglo = AgglomerativeClustering(n_clusters = n_clusters)
    agglo.fit(reduced_data)
    labels =  agglo.labels_
    ch_score = metrics.calinski_harabasz_score(reduced_data, labels)
    ch_tracker[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure + str(n_clusters)] = ch_score

    if n_dims == '2':
      #configuring plot settings, one color for each created label
      plt.figure()
      plt.scatter(reduced_data[:,0], reduced_data[:,1], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score) + '    nr clusters:' + str(n_clusters) + '\n Agglo', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'agglo'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)


    else:
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score)+ '    nr clusters:' + str(n_clusters)+ '\n Agglo', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'agglo'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)

# %%
#Determining the best clusters according to ch score and printing them in table
largest_keys = sorted(ch_tracker, key=ch_tracker.get, reverse=True)[:5]
largest_vals = [ch_tracker[x] for x in largest_keys]
length = len(largest_vals)
heading = np.empty(length, dtype = str)
heading[:] = 'value'
pd.DataFrame(largest_vals, index = largest_keys, columns=["values"])
# Out:
#                                               values
# adaptersnorm_vecsUMAP220.1euclidean100  15946.706822
# adaptersnorm_vecsUMAP220.1euclidean95   14775.090654
# adaptersnorm_vecsUMAP220.1euclidean90   13806.104279
# adaptersnorm_vecsUMAP220.1euclidean85   12956.346527
# adaptersnorm_vecsUMAP220.2euclidean100  12609.818757

# %% [markdown]
# ## 6.3 Spectral Clustering

# %%
#performing Spectral clustering by iterating over plausible hyperparameter values


#creating dict to track ch scores
ch_tracker = {}

#iterating over the different hyperparameter values and reduced dimensionality embeddings
for data_generation, pre_processing, dim_reduction, n_dims, n_neighbors, min_dist, measure in iter_array: #iteration over different reduced dim embeddings
  reduced_data = embeddings[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure]
  for n_clusters in np.concatenate((range(2,10,1),range(10,101,5))): #iterating over different number of clusters
    spectral = SpectralClustering(n_clusters = n_clusters)
    spectral.fit(reduced_data)
    labels =  spectral.labels_
    ch_score = metrics.calinski_harabasz_score(reduced_data, labels)
    ch_tracker[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure + str(n_clusters)] = ch_score

    if n_dims == '2':
      #configuring plot settings, one color for each created label
      plt.figure()
      plt.scatter(reduced_data[:,0], reduced_data[:,1], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score) + '    nr clusters:' + str(n_clusters)+ '\n Spectral', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'spectral'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)


    else:
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score)+ '    nr clusters:' + str(n_clusters)+ '\n Spectral', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'spectral'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 171 with accuracies
# [1.44919714e-15 1.61829967e-04 3.05845843e-05]
# not reaching the requested tolerance 3.072619438171387e-05.
# Use iteration 136 instead with accuracy
# 3.992587140607047e-05.
#
#   _, diffusion_map = lobpcg(
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [1.36148293e-15 3.25051026e-05 8.72725116e-05]
# not reaching the requested tolerance 3.072619438171387e-05.
#   _, diffusion_map = lobpcg(

# %%
#Determining the best clusters according to ch score and printing them in table
largest_keys = sorted(ch_tracker, key=ch_tracker.get, reverse=True)[:5]
largest_vals = [ch_tracker[x] for x in largest_keys]
length = len(largest_vals)
heading = np.empty(length, dtype = str)
heading[:] = 'value'
pd.DataFrame(largest_vals, index = largest_keys, columns=["values"])

# %% [markdown]
# ## 6.4 BIRCH Clustering

# %%
#performing BIRCH clustering by iterating over plausible hyperparameter values

#creating dict to track ch scores
ch_tracker = {}

#iterating over the different hyperparameter values and reduced dimensionality embeddings
for data_generation, pre_processing, dim_reduction, n_dims, n_neighbors, min_dist, measure in iter_array: #iteration over different reduced dim embeddings
  reduced_data = embeddings[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure]
  for n_clusters in np.concatenate((range(2,10,1),range(10,101,5))): #iterating over number of clusters
    birch = Birch(n_clusters = n_clusters)
    birch.fit(reduced_data)
    labels =  birch.labels_
    ch_score = metrics.calinski_harabasz_score(reduced_data, labels)
    ch_tracker[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure + str(n_clusters)] = ch_score

    if n_dims == '2':
      #configuring plot settings, one color for each created label
      plt.figure()
      plt.scatter(reduced_data[:,0], reduced_data[:,1], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score) + '    nr clusters:' + str(n_clusters) + '\n BIRCH', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'BIRCH'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)


    else:
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score)+ '    nr clusters:' + str(n_clusters) + '\n Birch', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'BIRCH'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(n_clusters) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)

# %%
#Determining the best clusters according to ch score and printing them in table
largest_keys = sorted(ch_tracker, key=ch_tracker.get, reverse=True)[:5]
largest_vals = [ch_tracker[x] for x in largest_keys]
length = len(largest_vals)
heading = np.empty(length, dtype = str)
heading[:] = 'value'
pd.DataFrame(largest_vals, index = largest_keys, columns=["values"])

# %% [markdown]
# ## 6.5 Optics Clustering

# %%
#performing OPTICS clustering by iterating over plausible hyperparameter values

#creating dict to track ch scores
ch_tracker = {}

#iterating over the different hyperparameter values and reduced dimensionality embeddings
for data_generation, pre_processing, dim_reduction, n_dims, n_neighbors, min_dist, measure in iter_array: #iteration over different reduced dim embeddings
  reduced_data = embeddings[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure]
  for min_samples in range(20,100,5): #iterating over number of samples in a neighborhood for a point to be considered as a core point
    optics = OPTICS(min_samples = min_samples)
    optics.fit(reduced_data)
    labels = optics.labels_
    ch_score = metrics.calinski_harabasz_score(reduced_data, labels)
    ch_tracker[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure + str(n_clusters)] = ch_score

    if n_dims == '2':
      #configuring plot settings, one color for each created label
      plt.figure()
      plt.scatter(reduced_data[:,0], reduced_data[:,1], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score) + '    min samples:' + str(min_samples) + + '\n Optics', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'Optics'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(min_samples) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)


    else:
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score)+ '    min samples:' + str(min_samples) + '\n Optics', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'Optics'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(min_samples) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)

# %%
#Determining the best clusters according to ch score and printing them in table
largest_keys = sorted(ch_tracker, key=ch_tracker.get, reverse=True)[:5]
largest_vals = [ch_tracker[x] for x in largest_keys]
length = len(largest_vals)
heading = np.empty(length, dtype = str)
heading[:] = 'value'
pd.DataFrame(largest_vals, index = largest_keys, columns=["values"])

# %% [markdown]
# ## 6.6 DBScan Clustering

# %%
#performing DBScan clustering by iterating over plausible hyperparameter values

#creating dict to track ch scores
ch_tracker = {}

#iterating over the different hyperparameter values and reduced dimensionality embeddings
for data_generation, pre_processing, dim_reduction, n_dims, n_neighbors, min_dist, measure in iter_array: #iteration over different reduced dim embeddings
  reduced_data = embeddings[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure]
  for min_samples in range(20,100,10): #iterating over number of samples in a neighborhood for a point to be considered as a core point
    for eps in range(1, 20, 1):
      dbscan = DBSCAN(eps= eps/2, min_samples = min_samples)
      dbscan.fit(reduced_data)
      labels = dbscan.labels_
    ch_score = metrics.calinski_harabasz_score(reduced_data, labels)
    ch_tracker[data_generation + pre_processing + dim_reduction + n_dims + n_neighbors+ min_dist + measure + str(n_clusters)] = ch_score

    if n_dims == '2':
      #configuring plot settings, one color for each created label
      plt.figure()
      plt.scatter(reduced_data[:,0], reduced_data[:,1], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score) + '    min samples:' + str(min_samples) + '\n DBScan', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'DBScan'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(min_samples) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)


    else:
      plt.figure()
      ax = plt.axes(projection='3d')
      ax.scatter3D(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c = np.take(colors, labels), s=0.1)
      plt.title(data_generation + '     ' + pre_processing + '     ' + dim_reduction + '\n' + 'n_neighbors:' + n_neighbors+ '     min_dist:' + min_dist + '     metric:' + measure + '\n' + 'ch score:'+str(ch_score)+ '    min samples:' + str(min_samples)+ '\n DBScan', fontsize=8)
      clustering_path = w_path + '/' + data_generation + '/' + pre_processing + '/' + dim_reduction + '/' + n_dims + '/' + 'DBScan'
      if os.path.exists(clustering_path) == False:
        os.mkdir(clustering_path)
      clustering_path = clustering_path + '/' + n_neighbors + '_' + min_dist + '_' + measure + str(min_samples) +'.pdf'
      plt.savefig(clustering_path , pad_inches = 15)

# %%
#Determining the best clusters according to ch score and printing them in table
largest_keys = sorted(ch_tracker, key=ch_tracker.get, reverse=True)[:5]
largest_vals = [ch_tracker[x] for x in largest_keys]
length = len(largest_vals)
heading = np.empty(length, dtype = str)
heading[:] = 'value'
pd.DataFrame(largest_vals, index = largest_keys, columns=["values"])
